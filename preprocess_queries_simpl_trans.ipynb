# %%
import benepar 
parser = benepar.Parser("benepar_en2")
def parse_line(line):
    tree = parser.parse(line)
    item = None
    for tr in tree.subtrees():
        if tr.label() == 'VP':
            item = tr
    return item 

# Process queries by constituency parser, extract main verb (verb not in subordinating conjunction)
# Main objects are also extracted 
t = "person turns off the light as they're leaving"

from nltk.tree import ParentedTree
def is_sbar(tr, v_cnt):
    ptr = tr.parent()
    flag = False 
    while ptr:
        if ptr.label() == 'SBAR' and v_cnt !=0:
            flag = True 
            break 
        else:
            ptr = ptr.parent() 
    return flag 

verbs_tags = ['VBZ', 'VBP', 'VB', 'VBD','VBG', 'VBN']
nouns_tags = ['NNS', 'NN']
def find_verb(item):
    verb = None 
    for st in item.subtrees():
        if st.label() in verbs_tags:
            verb = st.leaves()
            return verb, st  
    return verb, st  

def find_noun(item):
    noun = None 
    for st in item.subtrees():
        if st.label() in nouns_tags:
            noun = st.leaves()
            return noun
    return None 

# Extract main verbs and nouns as translation phrase 
def process_line(t):
    line = t.split("##")[-1]
    tree = parser.parse(line)
    newtree = ParentedTree.convert(tree)
    output= [] 
    verbs = [] 
    nouns = [] 
    v_cnt = 0 
    out = ""
    for tr in newtree.subtrees():
        if tr.label() == 'VP':
            #flag = is_sbar(tr, v_cnt)
            flag = False 
            if not flag:
                verb, st = find_verb(tr)
                if verb not in verbs:
                    verbs.append(verb)
                    v_cnt +=1 
                    if verb:
                        out += " "+ " ".join(verb)
                noun = find_noun(tr)
                if noun not in nouns: 
                    nouns.append(noun)
                    #print(noun)
                    if noun:
                        out += " "+ " ".join(noun)
    return verbs, nouns, out

# %%
verbs, nouns, out  = process_line(t)

# %%
stem_queries_verb = {}
from nltk.stem.wordnet import WordNetLemmatizer

out.split()
words = [WordNetLemmatizer().lemmatize(w,'v') for w in out.split()]

def process_pip(line):
    verbs, nouns, out  = process_line(line)
    words = [WordNetLemmatizer().lemmatize(w,'v') for w in out.split()]
    return words

# %%
test_words = {}


test_lines = open("/Users/yanjungao/Desktop/VPMT/data/charades/annotations/charades_sta_test.txt").readlines()
train_lines = open("/Users/yanjungao/Desktop/VPMT/data/charades/annotations/charades_sta_train.txt").readlines()

vocabs = [] 
for l in test_lines:
    _id = test_lines.index(l)
    words = process_pip(l)
    test_words[_id] = words
    vocabs.append(words)

# %%
test_words
# Out:
# {0: ['turn', 'light'],
#  1: ['flip', 'light'],
#  2: ['turn', 'light'],
#  3: ['be', 'switch', 'play'],
#  4: ['be', 'picture', 'put'],
#  5: ['put', 'bag'],
#  6: ['walk', 'doorway'],
#  7: ['open', 'door'],
#  8: ['close', 'door'],
#  9: ['close', 'door'],
#  10: ['run', 'stairs'],
#  11: ['watch', 'stairs', 'run'],
#  12: ['run', 'window', 'look'],
#  13: ['sit', 'chair'],
#  14: ['run', 'window'],
#  15: ['run', 'door'],
#  16: ['sit', 'chair'],
#  17: ['sit', 'chair'],
#  18: ['stand', 'bathroom', 'hold', 'glass'],
#  19: ['take', 'bag'],
#  20: ['sit', 'chair'],
#  21: ['sit', 'chair'],
#  22: ['throw', 'blanket'],
#  23: ['throw', 'clothe'],
#  24: ['stand'],
#  25: ['awaken', 'sofa'],
#  26: ['take', 'medicine'],
#  27: ['sit', 'chair'],
#  28: ['take', 'cup'],
#  29: ['open', 'door'],
#  30: ['open', 'door', 'lead'],
#  31: ['take', 'cup'],
#  32: ['walk', 'doorway', 'drink', 'coffee'],
#  33: ['drink', 'glass'],
#  34: ['put', 'shoe'],
#  35: ['hold', 'glass'],
#  36: ['eat', 'food'],
#  37: ['be', 'entryway', 'eat', 'sandwich'],
#  38: ['hold', 'glass'],
#  39: ['put', 'cup'],
#  40: ['stand', 'doorway', 'hold', 'glass'],
#  41: ['eat', 'sandwich'],
#  42: ['put', 'shoe'],
#  43: ['hold', 'cup'],
#  44: ['walk', 'house', 'put', 'food'],
#  45: ['start', 'dress', 'smile'],
#  46: ['drink', 'glass'],
#  47: ['take', 'drink'],
#  48: ['sit', 'bed'],
#  49: ['be', 'dress'],
#  50: ['sit', 'bed'],
#  51: ['throw', 'pair'],
#  52: ['throw', 'shoe'],
#  53: ['read', 'book'],
#  54: ['sit', 'top', 'close', 'laptop'],
#  55: ['be', 'stairs', 'stand', 'hold', 'bag'],
#  56: ['be', 'door', 'close'],
#  57: ['run', 'doorway'],
#  58: ['run', 'din'],
#  59: ['open', 'bag'],
#  60: ['be', 'laugh', 'undress'],
#  61: ['begin', 'undress'],
#  62: ['be', 'bag', 'put'],
#  63: ['lay', 'bed', 'sneeze'],
#  64: ['be', 'bed', 'lie', 'sneeze'],
#  65: ['drink', 'water'],
#  66: ['pick', 'phone', 'talk'],
#  67: ['take', 'phone'],
#  68: ['open', 'cabinet'],
#  69: ['start', 'laugh'],
#  70: ['sit', 'couch'],
#  71: ['be', 'something', 'drink'],
#  72: ['put', 'groceries'],
#  73: ['open', 'pantry'],
#  74: ['walk', 'house', 'hold', 'bag'],
#  75: ['put', 'groceries'],
#  76: ['turn', 'light'],
#  77: ['put', 'towel'],
#  78: ['take', 'phone'],
#  79: ['undress', 'shelf'],
#  80: ['open', 'door'],
#  81: ['close', 'laptop'],
#  82: ['take', 'picture'],
#  83: ['sit', 'chair'],
#  84: ['look', 'picture'],
#  85: ['put', 'picture'],
#  86: ['put', 'broom'],
#  87: ['put', 'picture'],
#  88: ['be', 'mirror', 'smile'],
#  89: ['open', 'door'],
#  90: ['open', 'door'],
#  91: ['laugh', 'kitchen'],
#  92: ['seem', 'blanket', 'be', 'laugh'],
#  93: ['eat'],
#  94: ['take', 'food'],
#  95: ['snuggle', 'blanket'],
#  96: ['eat'],
#  97: ['open', 'refrigerator'],
#  98: ['be', 'room', 'stand', 'hold', 'sandwich'],
#  99: ['put', 'sandwich'],
#  100: ['drink', 'cup'],
#  101: ['drink', 'glass'],
#  102: ['sit', 'table'],
#  103: ['take', 'towel'],
#  104: ['take', 'towel'],
#  105: ['open', 'cabinet'],
#  106: ['walk', 'bathroom', 'hold', 'dish'],
#  107: ['close', 'door'],
#  108: ['sit', 'chair'],
#  109: ['begin', 'something', 'laugh'],
#  110: ['be', 'chair', 'sit'],
#  111: ['be', 'smile'],
#  112: ['open', 'closet'],
#  113: ['throw', 'pillow'],
#  114: ['put', 'shoe'],
#  115: ['put', 'cup'],
#  116: ['close', 'door'],
#  117: ['put', 'cup'],
#  118: ['open', 'window'],
#  119: ['open', 'window'],
#  120: ['open', 'window'],
#  121: ['talk', 'phone'],
#  122: ['close', 'closet'],
#  123: ['turn', 'light'],
#  124: ['be', 'towel', 'dress'],
#  125: ['come', 'take', 'box'],
#  126: ['take', 'tray'],
#  127: ['take', 'box'],
#  128: ['sit', 'pillow'],
#  129: ['run', 'stairs'],
#  130: ['sit', 'floor'],
#  131: ['take', 'paper'],
#  132: ['open', 'window'],
#  133: ['take', 'camera'],
#  134: ['get', 'something', 'look', 'window'],
#  135: [],
#  136: ['look', 'window'],
#  137: ['look', 'book', 'open'],
#  138: ['start', 'paper', 'sneeze', 'look'],
#  139: ['be', 'blanket', 'sneeze'],
#  140: ['be', 'light', 'fix'],
#  141: ['be', 'light', 'fix'],
#  142: ['be', 'light', 'fix'],
#  143: ['put', 'book'],
#  144: ['put', 'book'],
#  145: ['take', 'phone'],
#  146: ['take', 'shoe'],
#  147: ['close', 'door'],
#  148: ['take', 'phone'],
#  149: ['play', 'phone'],
#  150: ['wash', 'cup'],
#  151: ['put', 'clothe'],
#  152: ['open', 'window'],
#  153: ['be', 'bed', 'sit'],
#  154: ['be', 'bed', 'sit'],
#  155: ['begin', 'window', 'open'],
#  156: ['open', 'window'],
#  157: ['be', 'bed', 'sit'],
#  158: ['open', 'closet'],
#  159: ['open', 'closet'],
#  160: ['open', 'closet'],
#  161: ['hold', 'shoe'],
#  162: ['take', 'drink'],
#  163: ['be', 'pair', 'throw'],
#  164: ['put', 'box'],
#  165: ['put', 'box'],
#  166: ['put', 'things'],
#  167: ['take', 'blanket'],
#  168: ['laugh', 'something'],
#  169: ['begin', 'something', 'laugh'],
#  170: ['put', 'food'],
#  171: ['throw', 'broom'],
#  172: ['throw', 'broom'],
#  173: ['turn', 'light', "'re", 'leave'],
#  174: ['turn', 'light'],
#  175: ['be', 'blanket', 'wrap', 'sneeze'],
#  176: ['use', 'doorknob', 'open', 'cabinet'],
#  177: ['close', 'box'],
#  178: ['close', 'box', "'s", 'be', 'search'],
#  179: ['awaken', 'bed'],
#  180: ['eat', 'bite'],
#  181: ['be', 'medicine', 'sneeze'],
#  182: ['start', 'sneeze'],
#  183: ['be', 'sneeze'],
#  184: ['be', 'food', 'put'],
#  185: ['be', 'groceries', 'put'],
#  186: ['ring', 'fridge', 'close'],
#  187: ['close', 'refrigerator'],
#  188: ['close', 'cabinet'],
#  189: ['sit', 'chair'],
#  190: ['sit', 'chair'],
#  191: ['open', 'closet'],
#  192: ['start', 'dress'],
#  193: ['open', 'door'],
#  194: ['put', 'shoe'],
#  195: ['take', 'glass'],
#  196: ['work', 'laptop'],
#  197: ['play', 'game'],
#  198: ['drink', 'bottle'],
#  199: ['take', 'laptop'],
#  200: ['be', 'bag', 'hold'],
#  201: ['start', 'undress'],
#  202: ['be', 'awaken'],
#  203: ['beg', 'glass', 'drink'],
#  204: ['open', 'kitchen'],
#  205: ['open', 'window'],
#  206: ['close', 'door'],
#  207: ['try', 'door', 'close'],
#  208: ['walk', 'bag', 'hold'],
#  209: ['awaken', 'bed'],
#  210: ['throw', 'blanket'],
#  211: ['be', 'dish', 'put'],
#  212: ['put', 'box'],
#  213: ['be', 'plat', 'put'],
#  214: ['take', 'drink'],
#  215: ['take', 'food'],
#  216: ['start', 'eat'],
#  217: ['close', 'cabinet'],
#  218: ['look', 'something', 'eat'],
#  219: ['eat'],
#  220: ['open', 'door', 'bite', 'snack'],
#  221: ['be', 'eat'],
#  222: ['be', 'bag', 'throw'],
#  223: ['open', 'fridge'],
#  224: ['open', 'oven', 'look'],
#  225: ['be', 'cook'],
#  226: ['undress'],
#  227: ['take', 'shoe'],
#  228: ['take', 'shoe'],
#  229: ['put', 'clothe'],
#  230: ['put', 'groceries'],
#  231: ['drink', 'glass'],
#  232: ['dress'],
#  233: ['be', 'blanket', 'hold'],
#  234: ['be', 'blanket', 'hold'],
#  235: ['take', 'broom'],
#  236: ['eat', 'food'],
#  237: ['be', 'basement', 'eat'],
#  238: ['lay', 'floor', 'get'],
#  239: ['watch', 'television', 'eat', 'apple'],
#  240: ['be', 'something', 'stand', 'eat', 'watch', 'tv'],
#  241: ['eat', 'sandwich'],
#  242: ['close', 'laptop'],
#  243: ['close', 'laptop'],
#  244: ['smile', 'laptop'],
#  245: ['begin', 'eat'],
#  246: ['be', 'door', 'hold'],
#  247: ['remove', 'snack', 'eat'],
#  248: ['eat', 'food'],
#  249: ['begin', 'fruit', 'eat'],
#  250: ['close', 'door'],
#  251: ['stand'],
#  252: ['look', 'window'],
#  253: ['be', 'closet', 'open'],
#  254: ['open', 'closet'],
#  255: ['be', 'table', 'run'],
#  256: ['laugh'],
#  257: ['eat'],
#  258: ['be', 'can', 'eat'],
#  259: ['eat', 'something'],
#  260: ['put', 'jar'],
#  261: ['put', 'food'],
#  262: ['eat'],
#  263: ['be', 'food', 'hold'],
#  264: ['throw', 'blanket'],
#  265: ['throw', 'blanket'],
#  266: ['put', 'shelf'],
#  267: ['be', 'blanket', 'tidy'],
#  268: ['be', 'light', 'turn'],
#  269: ['open', 'door'],
#  270: ['open', 'closet'],
#  271: ['close', 'cupboard'],
#  272: ['close', 'cupboard'],
#  273: ['be', 'cabinet', 'close'],
#  274: ['take', 'medicine'],
#  275: ['drink', 'cup'],
#  276: ['turn', 'light'],
#  277: ['turn', 'light'],
#  278: ['smile', 'mirror'],
#  279: ['drink', 'cup'],
#  280: ['take', 'book'],
#  281: ['turn', 'ceiling'],
#  282: ['turn', 'light'],
#  283: ['turn', 'light'],
#  284: ['run', 'room'],
#  285: ['run', 'bedroom'],
#  286: ['be', 'clothe', 'throw'],
#  287: ['close', 'window'],
#  288: ['be', 'window', 'open'],
#  289: ['be', 'sandwich', 'sneeze'],
#  290: ['eat', 'sandwich'],
#  291: ['be', 'toilet', 'sit', 'eat'],
#  292: ['be', 'bathroom', 'drink', 'cup'],
#  293: ['repeat', 'process', 'be', 'finish'],
#  294: ['walk', 'doorway'],
#  295: ['be', 'towel', 'put'],
#  296: ['be', 'garage', 'stand', 'hold', 'pillow'],
#  297: ['hold', 'pillow'],
#  298: ['turn', 'lightswitch'],
#  299: ['walk', 'doorway'],
#  300: ['turn', 'light'],
#  301: ['be', 'light', 'walk', 'turn'],
#  302: ['be', 'water', 'pour'],
#  303: ['be', 'floor', 'sit'],
#  304: ['snuggle', 'pillow'],
#  305: ['begin', 'bowl', 'eat'],
#  306: ['eat', 'something'],
#  307: ['hold', 'pillow'],
#  308: ['sit', 'floor'],
#  309: ['eat', 'be', 'lay'],
#  310: ['eat', 'food'],
#  311: ['sit', 'chair'],
#  312: ['sit', 'chair'],
#  313: ['be', 'window', 'look'],
#  314: ['look', 'bathroom'],
#  315: ['take', 'phone'],
#  316: ['take', 'drink'],
#  317: ['throw', 'floor'],
#  318: ['turn', 'light'],
#  319: ['turn', 'light'],
#  320: ['turn', 'light'],
#  321: ['take', 'book'],
#  322: ['take', 'book'],
#  323: ['be', 'book', 'tidy'],
#  324: ['sit', 'chair'],
#  325: ['laugh'],
#  326: ['take', 'picture'],
#  327: ['take', 'picture'],
#  328: ['put', 'phone'],
#  329: ['wash', 'hand'],
#  330: ['play', 'phone'],
#  331: ['take', 'picture'],
#  332: ['play', 'phone'],
#  333: ['work', 'laptop'],
#  334: ['stand', 'position'],
#  335: ['throw', 'shoe', 'kick'],
#  336: ['begin', 'undress'],
#  337: ['open', 'closet'],
#  338: ['throw', 'pillow'],
#  339: ['drink', 'glass'],
#  340: ['hold', 'bag'],
#  341: ['wash', 'clothe'],
#  342: ['be', 'clothe', 'wash'],
#  343: ['be', 'laundry', 'undress'],
#  344: ['take', 'towel'],
#  345: ['be', 'laundry', 'undress'],
#  346: ['person', 'clothe'],
#  347: ['talk', 'towel'],
#  348: ['run', 'room', 'laugh'],
#  349: ['run', 'room'],
#  350: ['run', 'live'],
#  351: ['take', 'drink'],
#  352: ['close', 'door'],
#  353: ['put', 'glass'],
#  354: ['open', 'door'],
#  355: ['open', 'door'],
#  356: ['take', 'towel'],
#  357: ['be', 'chair', 'seat'],
#  358: ['eat', 'food'],
#  359: ['take', 'bite'],
#  360: ['start', 'sneeze'],
#  361: ['put', 'something'],
#  362: ['put', 'shoe'],
#  363: ['put', 'shoe'],
#  364: ['awaken', 'home'],
#  365: ['hold', 'towel', 'walk', 'counter'],
#  366: ['wash', 'glass'],
#  367: ['awaken', 'bathroom', 'hold', 'phone'],
#  368: ['take', 'towel'],
#  369: ['laugh'],
#  370: ['hold', 'towel'],
#  371: ['walk', 'towel', 'hold'],
#  372: ['start', 'book', 'read'],
#  373: ['hold', 'cup'],
#  374: ['walk', 'entryway', 'hold', 'glass'],
#  375: ['open', 'door'],
#  376: ['open', 'door'],
#  377: ['open', 'door'],
#  378: ['open', 'door'],
#  379: ['undress'],
#  380: ['run', 'bedroom'],
#  381: ['throw', 'clothe'],
#  382: ['run', 'live'],
#  383: ['take', 'clothe'],
#  384: ['kneel', 'floor', 'talk', 'phone'],
#  385: ['talk', 'phone'],
#  386: ['pour', 'something'],
#  387: ['talk', 'phone'],
#  388: ['start', 'clothe', 'undress'],
#  389: ['close', 'door'],
#  390: ['close', 'door'],
#  391: ['close', 'door'],
#  392: ['begin', 'undress'],
#  393: ['close', 'door'],
#  394: ['close', 'pantry'],
#  395: ['sit', 'floor', 'read', 'book'],
#  396: ['eat', 'leftovers'],
#  397: ['take', 'food'],
#  398: ['open', 'refrigerator'],
#  399: ['start', 'food', 'eat'],
#  400: ['open', 'refrigerator'],
#  401: ['take', 'towel'],
#  402: ['open', 'door'],
#  403: ['hold', 'towel'],
#  404: ['sneeze', 'mirror', 'be', 'hold'],
#  405: ['start', 'sneeze'],
#  406: ['take', 'book'],
#  407: ['take', 'book'],
#  408: ['take', 'book'],
#  409: ['pour', 'coffee'],
#  410: ['put', 'cup'],
#  411: ['pour', 'cup'],
#  412: ['be', 'laptop', 'put'],
#  413: ['watch', 'television'],
#  414: ['put', 'laptop'],
#  415: ['turn', 'light'],
#  416: ['see', 'door', 'close'],
#  417: ['turn', 'light'],
#  418: ['be', 'shoe', 'see', 'throw'],
#  419: ['take', 'bite'],
#  420: ['sit', 'sandwich', 'eat'],
#  421: ['watch', 'television'],
#  422: ['take', 'picture'],
#  423: ['wash', 'glass'],
#  424: ['eat', 'plate'],
#  425: ['put', 'bag'],
#  426: ['tidy', 'blanket'],
#  427: ['put', 'laptop'],
#  428: ['stand'],
#  429: ['put', 'laptop'],
#  430: ['be', 'book', 'look'],
#  431: ['open', 'book'],
#  432: ['start', 'glass', 'drink'],
#  433: ['run', 'homework'],
#  434: ['open', 'refrigerator'],
#  435: ['start', 'book', 'read'],
#  436: ['laugh'],
#  437: ['laugh', 'bite'],
#  438: ['open', 'door'],
#  439: ['walk', 'doorway'],
#  440: ['open', 'door'],
#  441: ['start', 'eat'],
#  442: ['eat', 'bowl'],
#  443: ['walk', 'room', 'eat', 'food'],
#  444: ['close', 'door'],
#  445: ['set', 'bag', "'re", 'hold'],
#  446: ['put', 'bag', 'be', 'hold'],
#  447: ['put', 'bag'],
#  448: ['open', 'door'],
#  449: ['hold', 'chair', 'open', 'refrigerator'],
#  450: ['open', 'refrigerator'],
#  451: ['close', 'refrigerator'],
#  452: ['take', 'food'],
#  453: ['eat', 'sandwich'],
#  454: ['eat', 'food'],
#  455: ['open', 'cabinet'],
#  456: ['eat', 'breakfast'],
#  457: ['open', 'cabinets'],
#  458: ['run', 'blanket', 'cover'],
#  459: ['start', 'smile'],
#  460: ['open', 'box'],
#  461: ['be', 'box', 'sneeze'],
#  462: ['open', 'doors'],
#  463: ['put', 'cup'],
#  464: ['start', 'laugh'],
#  465: ['laugh', 'dresser', 'lean'],
#  466: ['sit', 'bed', 'climb', 'person'],
#  467: ['be', 'bed', 'awaken'],
#  468: ['sit', 'chair'],
#  469: ['take', 'blanket'],
#  470: ['sit', 'chair', 'drink', 'something'],
#  471: ['stand'],
#  472: ['be', 'smile'],
#  473: ['be', 'kitchen', 'stand', 'laugh'],
#  474: ['put', 'food'],
#  475: ['cook', 'sandwich'],
#  476: ['put', 'blanket'],
#  477: ['be', 'blanket', 'see', 'snuggle'],
#  478: ['open', 'door'],
#  479: ['open', 'closet'],
#  480: ['close', 'door'],
#  481: ['put', 'blanket'],
#  482: ['be', 'blanket', 'snuggle'],
#  483: ['take', 'drink'],
#  484: ['pour', 'content'],
#  485: ['pour', 'glass'],
#  486: ['take', 'drink'],
#  487: ['pour', 'water'],
#  488: ['pour', 'soda'],
#  489: ['open', 'cabinet'],
#  490: ['close', 'cabinet'],
#  491: ['take', 'pillow'],
#  492: ['take', 'pillow'],
#  493: ['walk', 'doorway', 'leave', 'room'],
#  494: ['walk', 'doorway'],
#  495: ['open', 'cabinet'],
#  496: ['be', 'cabinet', 'open'],
#  497: ['close', 'cabinet'],
#  498: ['hold', 'hand'],
#  499: ['put', 'towel'],
#  500: ['start', 'place', 'run'],
#  501: ['put', 'pair'],
#  502: ['begin', 'place', 'run'],
#  503: ['start', 'place', 'run'],
#  504: ['start', 'mirror', 'watch'],
#  505: ['start', 'palce', 'run'],
#  506: ['start', 'place', 'run'],
#  507: ['be', 'stave', 'cook'],
#  508: ['put', 'pillow'],
#  509: ['use', 'picture', 'take'],
#  510: ['take', 'picture'],
#  511: ['walk', 'bathroom', 'hold', 'camera'],
#  512: ['put', 'bag'],
#  513: ['put', 'table'],
#  514: ['be', 'bag', 'hold'],
#  515: ['be', 'groceries', 'put'],
#  516: ['open', 'bag'],
#  517: ['run', 'bathroom', 'grasp', 'pillow'],
#  518: ['run', 'bathroom', 'hold', 'pillow'],
#  519: ['be', 'blanket', 'hold'],
#  520: ['run', 'closet'],
#  521: ['run', 'room'],
#  522: ['put', 'clothe'],
#  523: ['hold', 'stack'],
#  524: ['use', 'spoon', 'eat', 'cup'],
#  525: ['eat', 'piece'],
#  526: ['put', 'table'],
#  527: ['turn', 'light'],
#  528: ['switch', 'light'],
#  529: ['turn', 'light'],
#  530: ['begin', 'undress'],
#  531: ['be', 'camera', 'put'],
#  532: ['dress'],
#  533: ['take', 'bottle'],
#  534: ['take', 'medicine'],
#  535: ['open', 'cabinet'],
#  536: ['close', 'cabinet'],
#  537: ['look', 'window'],
#  538: ['get', 'dress'],
#  539: ['run', 'garage'],
#  540: ['take', 'picture'],
#  541: ['stand'],
#  542: ['drink', 'cup'],
#  543: ['be', 'food', 'eat'],
#  544: ['be', 'television', 'watch'],
#  545: ['eat', 'box'],
#  546: ['watch', 'television'],
#  547: ['watch', 'television'],
#  548: ['be', 'broom', 'hold'],
#  549: ['put', 'broom'],
#  550: ['open', 'cabinet', 'get', 'cup'],
#  551: ['stand', 'doorway', 'hold', 'broom'],
#  552: ['pour', 'cup'],
#  553: ['close', 'book'],
#  554: ['begin', 'sneeze'],
#  555: ['be', 'wardrobe', 'undress'],
#  556: ['be', 'couch', 'sit'],
#  557: ['sit', 'sofa'],
#  558: ['take', 'shoe'],
#  559: ['take', 'shoe'],
#  560: ['drink', 'water'],
#  561: ['take', 'pair'],
#  562: ['sit', 'couch'],
#  563: ['drink', 'water'],
#  564: ['hold', 'towel'],
#  565: ['be', 'sneeze'],
#  566: ['take', 'towel'],
#  567: ['open', 'box'],
#  568: ['eat', 'something'],
#  569: ['be', 'room', 'walk', 'eat', 'sandwich'],
#  570: ['remove', 'sweatshirt'],
#  571: ['start', 'undress'],
#  572: ['take', 'sweatshirt'],
#  573: ['take', 'hoodie/sweater'],
#  574: ['eat', 'food'],
#  575: ['be', 'pillow', 'snuggle'],
#  576: ['snuggle', 'pillow'],
#  577: ['start', 'eat'],
#  578: ['pick', 'cup', 'drink'],
#  579: ['eat'],
#  580: ['eat'],
#  581: ['drink', 'cup'],
#  582: ['be', 'live', 'run'],
#  583: ['eat', 'sandwich'],
#  584: ['begin', 'circle', 'run'],
#  585: ['run', 'room'],
#  586: ['take', 'bite'],
#  587: ['continue', 'run'],
#  588: ['start', 'run'],
#  589: ['read', 'book'],
#  590: ['read', 'book'],
#  591: ['be', 'floor', 'sit', 'watch', 'television'],
#  592: ['look', 'picture'],
#  593: ['hold', 'picture'],
#  594: ['begin', 'sandwich', 'eat'],
#  595: ['put', 'blanket'],
#  596: ['open', 'door'],
#  597: ['take', 'pair'],
#  598: ['put', 'sandwich'],
#  599: ['take', 'bag'],
#  600: ['walk', 'kitchen', 'open', 'cabinet'],
#  601: ['take', 'picture'],
#  602: ['take', 'picture'],
#  603: ['put', 'table'],
#  604: ['be', 'smile'],
#  605: ['open', 'closet'],
#  606: ['close', 'closet'],
#  607: ['close', 'door'],
#  608: ['open', 'closet'],
#  609: ['put', 'shelf'],
#  610: ['be', 'book', 'put'],
#  611: ['start', 'cup', 'drink'],
#  612: ['put', 'book'],
#  613: ['be', 'box', 'put'],
#  614: ['hold', 'cardboard', 'enter', 'kitchen'],
#  615: ['stand'],
#  616: ['turn', 'light'],
#  617: ['start', 'undress'],
#  618: ['turn', 'light'],
#  619: ['put', 'book'],
#  620: ['laugh', 'cellphone'],
#  621: ['laugh', 'lot'],
#  622: ['be', 'camera', 'laugh'],
#  623: ['open', 'book'],
#  624: ['smile', 'book'],
#  625: ['put', 'shoe'],
#  626: ['take', 'shoe'],
#  627: ['hold', 'shoe'],
#  628: ['take', 'shoe'],
#  629: ['stand', 'smile'],
#  630: ['be', 'bag', 'open'],
#  631: ['take', 'drink'],
#  632: ['open', 'box'],
#  633: ['close', 'book'],
#  634: ['be', 'awaken'],
#  635: ['put', 'shoe'],
#  636: [],
#  637: ['turn', 'light'],
#  638: ['turn', 'light'],
#  639: ['tap', 'box'],
#  640: ['walk', 'doorway'],
#  641: ['be', 'table', 'sit'],
#  642: ['begin', 'table', 'tidy'],
#  643: ['look', 'window', 'outy'],
#  644: ['eat', 'food'],
#  645: ['be', 'picture', 'look'],
#  646: ['be', 'eat'],
#  647: ['begin', 'sandwich', 'eat'],
#  648: ['watch', 'something'],
#  649: ['look', 'picture'],
#  650: ['open', 'laptop', 'do', 'work'],
#  651: ['start', 'laptop', 'work'],
#  652: ['be', 'smile'],
#  653: ['be', 'glass', 'drink'],
#  654: ['drink', 'glass'],
#  655: ['begin', 'water', 'drink'],
#  656: ['be', 'sneeze'],
#  657: ['pick', 'broom'],
#  658: ['drink', 'glass'],
#  659: ['put', 'shoe'],
#  660: ['begin', 'shoe', 'put'],
#  661: ['proceed', 'pair', 'stand', 'put'],
#  662: ['be', 'phone', 'laugh'],
#  663: ['drink', 'glass'],
#  664: ['turn', 'light'],
#  665: ['be', 'light', 'fix'],
#  666: ['turn', 'light'],
#  667: ['drink', 'glass'],
#  668: ['close', 'book'],
#  669: ['close', 'wood'],
#  670: ['be', 'clothe', 'awaken'],
#  671: ['close', 'door'],
#  672: ['close', 'door'],
#  673: ['look', 'window'],
#  674: ['sit', 'chair'],
#  675: ['sit', 'bed'],
#  676: ['put', 'plate'],
#  677: ['sit', 'chair', 'eat', 'something'],
#  678: ['be', 'couch', 'sit', 'eat', 'food'],
#  679: ['eat', 'food'],
#  680: ['put', 'food'],
#  681: ['close', 'door'],
#  682: ['be', 'interrupt', 'sneeze'],
#  683: ['put', 'bag'],
#  684: ['sit', 'sofa', 'read', 'book'],
#  685: ['sit', 'sofa'],
#  686: ['open', 'box'],
#  687: ['open', 'book'],
#  688: ['open', 'box'],
#  689: ['open', 'box'],
#  690: ['start', 'sneeze'],
#  691: ['take', 'phone'],
#  692: ['fix', 'hair'],
#  693: ['sit', 'couch'],
#  694: ['be', 'bathroom', 'close'],
#  695: ['close', 'door'],
#  696: ['run', 'bag'],
#  697: ['decide', 'bag', 'run'],
#  698: ['be', 'picture', 'throw'],
#  699: ['be', 'eat'],
#  700: ['eat', 'snack'],
#  701: ['drink', 'glass'],
#  702: ['eat', 'sandwich'],
#  703: ['wash', 'dish'],
#  704: ['take', 'box'],
#  705: ['put', 'shoe'],
#  706: ['run'],
#  707: ['run', 'room'],
#  708: ['put', 'shoe'],
#  709: ['put', 'shoe'],
#  710: ['put', 'shoe'],
#  711: ['open', 'door', 'go', 'room'],
#  712: ['open', 'door'],
#  713: ['open', 'doorknob'],
#  714: ['start', 'place', 'run'],
#  715: ['start', 'place', 'run'],
#  716: ['throw', 'broom'],
#  717: ['start', 'sneeze'],
#  718: ['open', 'door'],
#  719: ['open', 'door'],
#  720: ['be', 'pillow', 'grasp'],
#  721: ['take', 'food'],
#  722: ['put', 'food'],
#  723: ['wash', 'hand'],
#  724: ['be', 'lot', 'do'],
#  725: ['cook', 'something'],
#  726: ['open', 'pantry'],
#  727: ['drink', 'coffee'],
#  728: ['drink', 'glass'],
#  729: ['open', 'refrigerator'],
#  730: ['open', 'refrigerator'],
#  731: ['open', 'refrigerator'],
#  732: ['open', 'door'],
#  733: ['close', 'door'],
#  734: ['sit', 'chair'],
#  735: ['close', 'door'],
#  736: ['sit', 'chair'],
#  737: ['laugh', 'tv'],
#  738: ['laugh', 'television'],
#  739: ['awaken', 'bedroom'],
#  740: ['laugh', 'tv'],
#  741: ['take', 'lightbulb'],
#  742: ['try', 'lightbulb', 'put'],
#  743: ['turn'],
#  744: ['light'],
#  745: ['fix', 'light'],
#  746: ['throw', 'bread'],
#  747: ['walk', 'doorway'],
#  748: ['stretch', 'arm', 'awaken'],
#  749: ['open', 'closet'],
#  750: ['put', 'broom'],
#  751: ['open', 'door'],
#  752: ['close', 'door'],
#  753: ['put', 'broom'],
#  754: ['open', 'door'],
#  755: ['close', 'door'],
#  756: ['look', 'picture'],
#  757: ['take', 'sip'],
#  758: ['jiggle', 'doorknob'],
#  759: ['open', 'door'],
#  760: ['try', 'door', 'open'],
#  761: ['be', 'chair', 'sit'],
#  762: ['turn', 'light'],
#  763: ['get', 'light', 'turn'],
#  764: ['walk', 'light'],
#  765: ['throw', 'blanket'],
#  766: ['take', 'picture'],
#  767: ['throw', 'towel'],
#  768: ['open', 'pantry', 'put', 'table'],
#  769: ['take', 'drink'],
#  770: ['drink', 'cup'],
#  771: ['eat', 'sandwich'],
#  772: ['open', 'cabinet'],
#  773: ['be', 'back', 'play'],
#  774: ['be', 'sandwich', 'eat'],
#  775: ['take', 'picture'],
#  776: ['take', 'picture'],
#  777: ['be', 'chair', 'clean', 'sit'],
#  778: ['sit', 'chair'],
#  779: ['be', 'study', 'smile', 'hold', 'bag'],
#  780: ['turn', 'light'],
#  781: ['fix', 'homework'],
#  782: ['eat', 'bed'],
#  783: ['eat', 'something'],
#  784: ['sit', 'bed'],
#  785: ['take', 'picture'],
#  786: ['wash', 'hand'],
#  787: ['washer', 'hand'],
#  788: ['put', 'book'],
#  789: ['be', 'shoe', 'put'],
#  790: ['put', 'shoe'],
#  791: ['put', 'shoe'],
#  792: ['hold', 'pair'],
#  793: ['stand'],
#  794: ['put', 'shoe'],
#  795: ['eat', 'food'],
#  796: ['be', 'book', 'throw'],
#  797: ['run', 'side'],
#  798: ['be', 'bed', 'sit'],
#  799: ['run', 'bedroom'],
#  800: ['pour', 'something'],
#  801: ['pour', 'water'],
#  802: ['be', 'sneeze'],
#  803: ['drink', 'glass'],
#  804: ['go', 'run'],
#  805: ['open'],
#  806: ['open'],
#  807: ['run', 'room'],
#  808: ['be', 'see', 'eat'],
#  809: ['be', 'chair', 'sit'],
#  810: ['eat', 'something'],
#  811: ['grab', 'pillow', 'snuggle'],
#  812: ['sit', 'chair', 'eat'],
#  813: ['hold', 'pillow'],
#  814: ['eat', 'plate'],
#  815: ['watch', 'television'],
#  816: ['start', 'television', 'watch'],
#  817: ['watch', 'television'],
#  818: ['sit', 'edge'],
#  819: ['be', 'tea', 'drink'],
#  820: ['throw', 'bag'],
#  821: ['laugh'],
#  822: ['start', 'bag', 'laugh', 'put'],
#  823: ['take', 'shoe'],
#  824: ['be', 'bag', 'hold'],
#  825: ['take', 'shoe'],
#  826: ['open', 'cabinet'],
#  827: ['put', 'laptop'],
#  828: ['be', 'food', 'eat'],
#  829: ['take', 'bite'],
#  830: ['open', 'door'],
#  831: ['hold', 'pillow'],
#  832: ['close', 'fridge'],
#  833: ['turn', 'light'],
#  834: ['wash', 'hand'],
#  835: ['turn', 'light'],
#  836: ['take', 'batteries'],
#  837: ['be', 'floor', 'sit', 'throw', 'pillow'],
#  838: ['take', 'shoe'],
#  839: ['sit', 'chair'],
#  840: ['sit', 'chair'],
#  841: ['take', 'shoe'],
#  842: ['be', 'bag', 'hold'],
#  843: ['be', 'soda', 'drink'],
#  844: ['continue', 'bottle', 'drink'],
#  845: ['drink', 'glass'],
#  846: ['eat', 'food'],
#  847: ['eat', 'sandwich'],
#  848: ['run', 'closet'],
#  849: ['take', 'blanket'],
#  850: ['put', 'clothe'],
#  851: ['take', 'vacuum'],
#  852: ['sneeze'],
#  853: ['look', 'window'],
#  854: ['wash', 'hand'],
#  855: ['continue', 'window', 'look'],
#  856: ['be', 'hand', 'wash'],
#  857: ['wash', 'hand'],
#  858: ['look', 'window'],
#  859: ['be', 'room', 'stand', 'watch', 'television'],
#  860: ['drink', 'something'],
#  861: ['drink', 'glass'],
#  862: ['be', 'television', 'watch'],
#  863: ['throw', 'pillow'],
#  864: ['eat', 'sandwich'],
#  865: ['turn', 'light'],
#  866: ['turn', 'light'],
#  867: ['turn', 'light'],
#  868: ['sit', 'bed'],
#  869: ['put', 'sandwich'],
#  870: ['put', 'table'],
#  871: ['throw', 'food'],
#  872: ['close', 'door'],
#  873: ['pour', 'glass'],
#  874: ['pour', 'glass'],
#  875: ['drink', 'coke'],
#  876: ['close', 'door'],
#  877: ['put', 'item'],
#  878: ['be', 'bag', 'open'],
#  879: ['put', 'bag'],
#  880: ['throw', 'pillow'],
#  881: ['be', 'pillow', 'hold'],
#  882: ['throw', 'pillow'],
#  883: ['be', 'closet', 'open', 'look', 'sandwich'],
#  884: ['open', 'door'],
#  885: ['open', 'door'],
#  886: ['watch', 'television'],
#  887: ['close', 'laptop'],
#  888: ['start', 'food', 'eat'],
#  889: ['pick', 'sandwich', 'eat'],
#  890: ['awaken', 'floor'],
#  891: ['walk', 'window'],
#  892: ['be', 'floor', 'lay'],
#  893: ['open', 'window'],
#  894: ['open', 'curtain', 'look', 'window'],
#  895: ['undress', 'front'],
#  896: ['take', 'pillow'],
#  897: ['snuggle', 'pillow'],
#  898: ['take', 'picture'],
#  899: ['eat'],
#  900: ['begin', 'eat'],
#  901: ['turn', 'light'],
#  902: ['turn', 'light'],
#  903: ['turn', 'light'],
#  904: ['turn', 'light'],
#  905: ['open', 'laptop'],
#  906: ['open', 'laptop'],
#  907: ['put', 'broom'],
#  908: ['eat', 'food'],
#  909: ['eat', 'something'],
#  910: ['be', 'eat'],
#  911: ['open', 'refrigerator'],
#  912: ['be', 'door', 'close'],
#  913: ['sneeze', 'towel'],
#  914: ['open', 'refrigerator'],
#  915: ['sneeze', 'towel'],
#  916: ['be', 'mirror', 'sneeze', 'dust'],
#  917: ['throw', 'bag'],
#  918: ['put', 'table'],
#  919: ['begin', 'bag', 'put'],
#  920: ['hold', 'bag'],
#  921: ['walk', 'doorway'],
#  922: ['be', 'book', 'look', 'hold', 'pen'],
#  923: ['walk', 'doorway'],
#  924: ['be', 'something', 'cook'],
#  925: ['drink', 'cup'],
#  926: ['sit', 'table'],
#  927: ['sit', 'chair'],
#  928: ['cook', 'stave'],
#  929: ['put', 'blanket'],
#  930: ['put', 'table'],
#  931: ['put', 'shelf'],
#  932: ['close', 'box'],
#  933: ['put', 'something', 'close', 'door'],
#  934: ['close', 'door'],
#  935: ['put', 'book'],
#  936: ['take', 'cabinet', 'open'],
#  937: ['run', 'closet'],
#  938: ['run', 'kitchen'],
#  939: ['begin', 'run'],
#  940: ['run', 'couch'],
#  941: ['put', 'cup'],
#  942: ['walk', 'sandwich', 'eat'],
#  943: ['be', 'sandwich', 'eat'],
#  944: ['take', 'drink'],
#  945: ['be', 'sneeze'],
#  946: ['close', 'door'],
#  947: ['close', 'door'],
#  948: ['try', 'doorknob', 'fix'],
#  949: ['eat'],
#  950: ['continue', 'eat'],
#  951: ['eat', 'sandwich'],
#  952: ['be', 'doorknob', 'fix'],
#  953: ['watch', 'friend', 'fix', 'door'],
#  954: ['open', 'bag'],
#  955: ['eat', 'food'],
#  956: ['eat', 'something'],
#  957: ['watch', 'tv', 'eat', 'sandwich'],
#  958: ['close', 'door'],
#  959: ['turn', 'light'],
#  960: ['close', 'door'],
#  961: ['be', 'smile'],
#  962: ['put', 'shoe'],
#  963: ['be', 'smile'],
#  964: ['put', 'shoe'],
#  965: ['put', 'something'],
#  966: ['put', 'cup'],
#  967: ['sit', 'chair'],
#  968: ['open', 'door'],
#  969: ['sit', 'chair'],
#  970: ['take', 'broom'],
#  971: ['put', 'broom'],
#  972: ['sit', 'chair'],
#  973: ['put', 'table'],
#  974: ['cook', 'stave'],
#  975: ['be', 'blanket', 'hold'],
#  976: ['turn', 'light'],
#  977: ['close', 'door'],
#  978: ['close', 'door'],
#  979: ['close', 'door'],
#  980: ['be', 'shoe', 'throw'],
#  981: ['throw', 'shoe'],
#  982: ['take', 'drink'],
#  983: ['be', 'laptop', 'play'],
#  984: ['come', 'run'],
#  985: ['close', 'door'],
#  986: ['take', 'cup'],
#  987: ['read', 'book'],
#  988: ['read', 'book'],
#  989: ['start', 'weather', 'dress'],
#  990: ['begin', 'dress'],
#  991: ['put', 'book'],
#  992: ['read', 'book'],
#  993: ['sit', 'bed'],
#  994: ['sit', 'bed'],
#  995: ['eat', 'food'],
#  996: ['sit', 'bed'],
#  997: ['take', 'shoe'],
#  998: ['turn', 'light'],
#  999: ['be', 'door', 'close'],
#  ...}

# %%
train_words = {} 
for l in train_lines:
    _id = train_lines.index(l)
    words = process_pip(l)
    train_words[_id] = words
    vocabs.append(words)

# %%
vocabs.extend(list(test_words.values()))

# %%
vocabs_all = [j for i in vocabs for j in i]
vocabs = set(vocabs_all)

# %%
vocab_idx = {k:list(vocabs).index(k)+1 for k in vocabs}

# %%
vocab_idx['PAD'] = 0 
vocab_idx['<sos>'] = len(vocab_idx) 
vocab_idx['<eos>'] = len(vocab_idx)

# %%
vocab_idx
# Out:
# {'belong': 1,
#  'lollipop': 2,
#  'snack': 3,
#  'selfie': 4,
#  'mirror': 5,
#  'cell': 6,
#  'crouch': 7,
#  'stairs': 8,
#  'guy': 9,
#  'fall': 10,
#  'puzzle': 11,
#  'pills': 12,
#  'pantry': 13,
#  'entry': 14,
#  'paper': 15,
#  'pause': 16,
#  'opend': 17,
#  'form': 18,
#  'feet': 19,
#  'do': 20,
#  'hit': 21,
#  'head': 22,
#  'jiggle': 23,
#  'dog': 24,
#  'photo': 25,
#  'sock': 26,
#  'soda': 27,
#  'wash': 28,
#  'load': 29,
#  'type': 30,
#  'products': 31,
#  'game': 32,
#  'pose': 33,
#  'say': 34,
#  'cook': 35,
#  'enter': 36,
#  'turn': 37,
#  'cap': 38,
#  'faucet': 39,
#  'be': 40,
#  'blind': 41,
#  'eat': 42,
#  'closet': 43,
#  'tap': 44,
#  'linen': 45,
#  'entryway': 46,
#  'stairwell': 47,
#  'switch': 48,
#  "'s": 49,
#  'blanket/pillow': 50,
#  'boot': 51,
#  'program': 52,
#  'toss': 53,
#  'string': 54,
#  'pot': 55,
#  'photograph': 56,
#  'doorways': 57,
#  'plug': 58,
#  'selfies': 59,
#  'finger': 60,
#  'others': 61,
#  'plat': 62,
#  'redress': 63,
#  'seem': 64,
#  'nightstand': 65,
#  'view': 66,
#  'pitcher': 67,
#  'lightswitch': 68,
#  'adjust': 69,
#  'winter': 70,
#  'doors': 71,
#  'wake': 72,
#  'person': 73,
#  'stir': 74,
#  'water': 75,
#  'desk': 76,
#  'keep': 77,
#  'pepper': 78,
#  'burrito': 79,
#  'card': 80,
#  'wipe': 81,
#  'anti-acids': 82,
#  'try': 83,
#  'front': 84,
#  'microwave': 85,
#  'garbage': 86,
#  'direct': 87,
#  'tissue': 88,
#  'phone': 89,
#  'return': 90,
#  'back': 91,
#  'lightbulb': 92,
#  'absurdity': 93,
#  'tray': 94,
#  'find': 95,
#  'play': 96,
#  'sit': 97,
#  'refrigerator': 98,
#  'thing': 99,
#  'take': 100,
#  'beg': 101,
#  'rec': 102,
#  'recipe': 103,
#  'chair': 104,
#  'car': 105,
#  'hoodie': 106,
#  'come': 107,
#  'area': 108,
#  'point': 109,
#  'shoulder': 110,
#  'jar': 111,
#  'close': 112,
#  'hide': 113,
#  'juice': 114,
#  'shake': 115,
#  'spoon': 116,
#  'snuggle': 117,
#  'lift': 118,
#  'pile': 119,
#  'camera': 120,
#  'stand': 121,
#  'crackers': 122,
#  'read': 123,
#  'vacuum': 124,
#  'dinner': 125,
#  'mug': 126,
#  'windows': 127,
#  'sip': 128,
#  'move': 129,
#  'need': 130,
#  'bedroom': 131,
#  'sandwhich': 132,
#  'dryer': 133,
#  'consume': 134,
#  'china': 135,
#  'work/play': 136,
#  'position': 137,
#  'undress': 138,
#  'piece': 139,
#  'stretch': 140,
#  'isdrinking': 141,
#  'arm': 142,
#  'tilt': 143,
#  'top': 144,
#  'cloth': 145,
#  'broom': 146,
#  'fruit': 147,
#  'think': 148,
#  'end': 149,
#  'notebooks': 150,
#  'prop': 151,
#  'cellphone': 152,
#  'dust': 153,
#  'serve': 154,
#  'pen': 155,
#  'pant': 156,
#  'miss': 157,
#  'ant': 158,
#  'trun': 159,
#  'comfort': 160,
#  'click': 161,
#  'mobile': 162,
#  'computer': 163,
#  'medicine': 164,
#  'ceiling': 165,
#  'staircase': 166,
#  'morning': 167,
#  'flashlight': 168,
#  'hair': 169,
#  'get': 170,
#  'middle': 171,
#  'din': 172,
#  'sheet': 173,
#  'drawers': 174,
#  'dosage': 175,
#  'recloses': 176,
#  'lean': 177,
#  'purpose': 178,
#  'bag': 179,
#  'couch': 180,
#  'baggy': 181,
#  'remain': 182,
#  'lead': 183,
#  'pick': 184,
#  'lie': 185,
#  'couple': 186,
#  'decompress': 187,
#  'detergent': 188,
#  'unwrap': 189,
#  'awake': 190,
#  'edoorknob': 191,
#  'finish': 192,
#  'doorknob': 193,
#  'reopen': 194,
#  'clothesline': 195,
#  'cause': 196,
#  'screen': 197,
#  'banana': 198,
#  'interrupt': 199,
#  'pillow': 200,
#  'groceries': 201,
#  'laptops': 202,
#  'blanket': 203,
#  'throw': 204,
#  'case': 205,
#  'have': 206,
#  "'re": 207,
#  'cold': 208,
#  'refrigerators': 209,
#  'grocery': 210,
#  'let': 211,
#  'flight': 212,
#  'show': 213,
#  'burst': 214,
#  'start': 215,
#  'chip': 216,
#  'collect': 217,
#  'sofa': 218,
#  'counter': 219,
#  'roll': 220,
#  'change': 221,
#  'cloths': 222,
#  'videos': 223,
#  'repeat': 224,
#  'grind': 225,
#  'kitchen': 226,
#  'grape': 227,
#  'fling': 228,
#  'work': 229,
#  'cover': 230,
#  'kick': 231,
#  'stop': 232,
#  'coke': 233,
#  'beverage': 234,
#  'bottom': 235,
#  'plate': 236,
#  'hug': 237,
#  'handle': 238,
#  'coffee': 239,
#  'edge': 240,
#  'kind': 241,
#  'rest': 242,
#  'debate': 243,
#  'wrap': 244,
#  'ishoes': 245,
#  'cardboard': 246,
#  'cut': 247,
#  'pass': 248,
#  'dough': 249,
#  'fix': 250,
#  'tool': 251,
#  'sweat': 252,
#  'attempt': 253,
#  'toy': 254,
#  'air': 255,
#  'orange': 256,
#  'foot': 257,
#  'time': 258,
#  'dresser': 259,
#  'cuddle': 260,
#  'oven': 261,
#  'cheese': 262,
#  'push': 263,
#  'weather': 264,
#  'drape': 265,
#  'begin': 266,
#  'hang': 267,
#  'grab': 268,
#  'picture': 269,
#  's': 270,
#  'candy': 271,
#  'window': 272,
#  'twirl': 273,
#  'bunch': 274,
#  'process': 275,
#  'movement': 276,
#  'boo': 277,
#  'hall': 278,
#  'stare': 279,
#  'rise': 280,
#  'pizza': 281,
#  'laugh': 282,
#  'llooked': 283,
#  'chocolate': 284,
#  'ward': 285,
#  'sweep': 286,
#  'bring': 287,
#  'shove': 288,
#  'leg': 289,
#  'dirt': 290,
#  'bread': 291,
#  'key': 292,
#  'wine': 293,
#  'tennis': 294,
#  'fridge': 295,
#  'carry': 296,
#  'wear': 297,
#  'friend': 298,
#  'drop': 299,
#  'pull': 300,
#  'paperwork': 301,
#  'object': 302,
#  'milk': 303,
#  'climb': 304,
#  'slumber': 305,
#  'reflection': 306,
#  'put': 307,
#  'live': 308,
#  'write': 309,
#  'follow': 310,
#  'circle': 311,
#  'watch': 312,
#  'lot': 313,
#  'tablet': 314,
#  'shelve': 315,
#  'office': 316,
#  'television': 317,
#  'pretend': 318,
#  'sponge': 319,
#  'wood': 320,
#  'leftovers': 321,
#  'personlaying': 322,
#  'continue': 323,
#  'examine': 324,
#  'side': 325,
#  'napkin': 326,
#  'swing': 327,
#  'home': 328,
#  'toilet': 329,
#  'hand': 330,
#  'use': 331,
#  'remove': 332,
#  'magazine': 333,
#  'bedside': 334,
#  'shin': 335,
#  'awaken': 336,
#  'lap': 337,
#  'spice': 338,
#  'go': 339,
#  'envelope': 340,
#  'react': 341,
#  'liquids': 342,
#  'cabinet': 343,
#  'sweatshirt': 344,
#  'tea': 345,
#  'backpack/bag': 346,
#  'basement': 347,
#  'lunch': 348,
#  'touch': 349,
#  'cookies': 350,
#  'sleep': 351,
#  'pour': 352,
#  'resume': 353,
#  'cabinets': 354,
#  'drink': 355,
#  'place': 356,
#  'study': 357,
#  'glass': 358,
#  'break': 359,
#  'cookie': 360,
#  'ring': 361,
#  'sink': 362,
#  'stave': 363,
#  'give': 364,
#  'cleaner': 365,
#  'door': 366,
#  'box': 367,
#  'flick': 368,
#  'runnings': 369,
#  'bowl': 370,
#  'ans': 371,
#  'bottle': 372,
#  'whats': 373,
#  'open/close': 374,
#  'cracker': 375,
#  'hallway': 376,
#  'lid': 377,
#  'nest': 378,
#  'call': 379,
#  'bathroom': 380,
#  'pan': 381,
#  'video': 382,
#  'carpet': 383,
#  'things': 384,
#  'packet': 385,
#  'laptop': 386,
#  'walk-in': 387,
#  'jacket': 388,
#  'pocket': 389,
#  'complain': 390,
#  "'ve": 391,
#  'shutter': 392,
#  'check': 393,
#  'homework': 394,
#  'cereal': 395,
#  'rice': 396,
#  'floor': 397,
#  'pajamas': 398,
#  'star': 399,
#  'palce': 400,
#  'bucket': 401,
#  'leave': 402,
#  'self': 403,
#  'message': 404,
#  'noise': 405,
#  'towel': 406,
#  'thermos': 407,
#  'washer': 408,
#  'hinge': 409,
#  'coat': 410,
#  'slide': 411,
#  'frig': 412,
#  'even': 413,
#  'hat': 414,
#  'house': 415,
#  'stairway': 416,
#  'trash': 417,
#  'walk': 418,
#  'swallow': 419,
#  'see': 420,
#  'shoot': 421,
#  'item': 422,
#  'approach': 423,
#  'driveway': 424,
#  'mountain': 425,
#  'notebook': 426,
#  'plastic': 427,
#  'closses': 428,
#  'stuff': 429,
#  'breakfast': 430,
#  'open': 431,
#  'movie': 432,
#  'organize': 433,
#  'outy': 434,
#  'appear': 435,
#  'clean': 436,
#  'stair': 437,
#  'replace': 438,
#  'talk': 439,
#  'look': 440,
#  'make': 441,
#  'set': 442,
#  'egg': 443,
#  'table': 444,
#  'pair': 445,
#  'bite': 446,
#  'straighten': 447,
#  'cup': 448,
#  'fit': 449,
#  'picture/video': 450,
#  'recreation': 451,
#  'spot': 452,
#  'pop': 453,
#  'smile': 454,
#  'page': 455,
#  'container': 456,
#  'sandwich': 457,
#  'flip': 458,
#  'run': 459,
#  'contain': 460,
#  'shut': 461,
#  'shelf': 462,
#  'tv': 463,
#  'search': 464,
#  'wardrobe': 465,
#  'proceed': 466,
#  'shower': 467,
#  'bedtime': 468,
#  'unlace': 469,
#  'reach': 470,
#  'wall': 471,
#  'step': 472,
#  'photos': 473,
#  'conversation': 474,
#  'reenter': 475,
#  'meal': 476,
#  'buy': 477,
#  'something': 478,
#  'dress': 479,
#  'papers/book': 480,
#  'decide': 481,
#  'hold': 482,
#  'sneeze': 483,
#  'dance': 484,
#  'shirt': 485,
#  'win': 486,
#  'seat': 487,
#  'canvas': 488,
#  'wait': 489,
#  'lamp': 490,
#  'whole': 491,
#  'tidy': 492,
#  'cupboard': 493,
#  'curtain': 494,
#  'junk': 495,
#  'doen': 496,
#  'reveal': 497,
#  'word': 498,
#  'burger': 499,
#  'heat': 500,
#  'items': 501,
#  'reference': 502,
#  'minutes': 503,
#  'peel': 504,
#  'pack': 505,
#  'donut': 506,
#  'skillet/pot/pan': 507,
#  'review': 508,
#  'rage': 509,
#  'struggle': 510,
#  'encounter': 511,
#  'doorway': 512,
#  'hoodie/sweater': 513,
#  'texting': 514,
#  'liquid': 515,
#  'apple': 516,
#  'lay': 517,
#  'dump': 518,
#  'can': 519,
#  'laundry': 520,
#  'nap': 521,
#  'book': 522,
#  'fold': 523,
#  'flash': 524,
#  'complete': 525,
#  'garage': 526,
#  'prepare': 527,
#  'eye': 528,
#  'sort': 529,
#  'jump': 530,
#  'bend': 531,
#  'food': 532,
#  'content': 533,
#  'light': 534,
#  'muffin': 535,
#  'shoe': 536,
#  'lend': 537,
#  'device': 538,
#  'sweater': 539,
#  'stack': 540,
#  'bed': 541,
#  'batteries': 542,
#  'beer': 543,
#  'balance': 544,
#  'remember': 545,
#  'add': 546,
#  'room': 547,
#  'knife': 548,
#  'exit': 549,
#  'manner': 550,
#  'dish': 551,
#  'potato': 552,
#  'kneel': 553,
#  'grasp': 554,
#  'clothe': 555,
#  'frame': 556,
#  'kleenex': 557,
#  'PAD': 0,
#  '<sos>': 558,
#  '<eos>': 559}

# %%
idx_vocab = {v:k for k,v in vocab_idx.items()}

# %%
idx_vocab
# Out:
# {1: 'belong',
#  2: 'lollipop',
#  3: 'snack',
#  4: 'selfie',
#  5: 'mirror',
#  6: 'cell',
#  7: 'crouch',
#  8: 'stairs',
#  9: 'guy',
#  10: 'fall',
#  11: 'puzzle',
#  12: 'pills',
#  13: 'pantry',
#  14: 'entry',
#  15: 'paper',
#  16: 'pause',
#  17: 'opend',
#  18: 'form',
#  19: 'feet',
#  20: 'do',
#  21: 'hit',
#  22: 'head',
#  23: 'jiggle',
#  24: 'dog',
#  25: 'photo',
#  26: 'sock',
#  27: 'soda',
#  28: 'wash',
#  29: 'load',
#  30: 'type',
#  31: 'products',
#  32: 'game',
#  33: 'pose',
#  34: 'say',
#  35: 'cook',
#  36: 'enter',
#  37: 'turn',
#  38: 'cap',
#  39: 'faucet',
#  40: 'be',
#  41: 'blind',
#  42: 'eat',
#  43: 'closet',
#  44: 'tap',
#  45: 'linen',
#  46: 'entryway',
#  47: 'stairwell',
#  48: 'switch',
#  49: "'s",
#  50: 'blanket/pillow',
#  51: 'boot',
#  52: 'program',
#  53: 'toss',
#  54: 'string',
#  55: 'pot',
#  56: 'photograph',
#  57: 'doorways',
#  58: 'plug',
#  59: 'selfies',
#  60: 'finger',
#  61: 'others',
#  62: 'plat',
#  63: 'redress',
#  64: 'seem',
#  65: 'nightstand',
#  66: 'view',
#  67: 'pitcher',
#  68: 'lightswitch',
#  69: 'adjust',
#  70: 'winter',
#  71: 'doors',
#  72: 'wake',
#  73: 'person',
#  74: 'stir',
#  75: 'water',
#  76: 'desk',
#  77: 'keep',
#  78: 'pepper',
#  79: 'burrito',
#  80: 'card',
#  81: 'wipe',
#  82: 'anti-acids',
#  83: 'try',
#  84: 'front',
#  85: 'microwave',
#  86: 'garbage',
#  87: 'direct',
#  88: 'tissue',
#  89: 'phone',
#  90: 'return',
#  91: 'back',
#  92: 'lightbulb',
#  93: 'absurdity',
#  94: 'tray',
#  95: 'find',
#  96: 'play',
#  97: 'sit',
#  98: 'refrigerator',
#  99: 'thing',
#  100: 'take',
#  101: 'beg',
#  102: 'rec',
#  103: 'recipe',
#  104: 'chair',
#  105: 'car',
#  106: 'hoodie',
#  107: 'come',
#  108: 'area',
#  109: 'point',
#  110: 'shoulder',
#  111: 'jar',
#  112: 'close',
#  113: 'hide',
#  114: 'juice',
#  115: 'shake',
#  116: 'spoon',
#  117: 'snuggle',
#  118: 'lift',
#  119: 'pile',
#  120: 'camera',
#  121: 'stand',
#  122: 'crackers',
#  123: 'read',
#  124: 'vacuum',
#  125: 'dinner',
#  126: 'mug',
#  127: 'windows',
#  128: 'sip',
#  129: 'move',
#  130: 'need',
#  131: 'bedroom',
#  132: 'sandwhich',
#  133: 'dryer',
#  134: 'consume',
#  135: 'china',
#  136: 'work/play',
#  137: 'position',
#  138: 'undress',
#  139: 'piece',
#  140: 'stretch',
#  141: 'isdrinking',
#  142: 'arm',
#  143: 'tilt',
#  144: 'top',
#  145: 'cloth',
#  146: 'broom',
#  147: 'fruit',
#  148: 'think',
#  149: 'end',
#  150: 'notebooks',
#  151: 'prop',
#  152: 'cellphone',
#  153: 'dust',
#  154: 'serve',
#  155: 'pen',
#  156: 'pant',
#  157: 'miss',
#  158: 'ant',
#  159: 'trun',
#  160: 'comfort',
#  161: 'click',
#  162: 'mobile',
#  163: 'computer',
#  164: 'medicine',
#  165: 'ceiling',
#  166: 'staircase',
#  167: 'morning',
#  168: 'flashlight',
#  169: 'hair',
#  170: 'get',
#  171: 'middle',
#  172: 'din',
#  173: 'sheet',
#  174: 'drawers',
#  175: 'dosage',
#  176: 'recloses',
#  177: 'lean',
#  178: 'purpose',
#  179: 'bag',
#  180: 'couch',
#  181: 'baggy',
#  182: 'remain',
#  183: 'lead',
#  184: 'pick',
#  185: 'lie',
#  186: 'couple',
#  187: 'decompress',
#  188: 'detergent',
#  189: 'unwrap',
#  190: 'awake',
#  191: 'edoorknob',
#  192: 'finish',
#  193: 'doorknob',
#  194: 'reopen',
#  195: 'clothesline',
#  196: 'cause',
#  197: 'screen',
#  198: 'banana',
#  199: 'interrupt',
#  200: 'pillow',
#  201: 'groceries',
#  202: 'laptops',
#  203: 'blanket',
#  204: 'throw',
#  205: 'case',
#  206: 'have',
#  207: "'re",
#  208: 'cold',
#  209: 'refrigerators',
#  210: 'grocery',
#  211: 'let',
#  212: 'flight',
#  213: 'show',
#  214: 'burst',
#  215: 'start',
#  216: 'chip',
#  217: 'collect',
#  218: 'sofa',
#  219: 'counter',
#  220: 'roll',
#  221: 'change',
#  222: 'cloths',
#  223: 'videos',
#  224: 'repeat',
#  225: 'grind',
#  226: 'kitchen',
#  227: 'grape',
#  228: 'fling',
#  229: 'work',
#  230: 'cover',
#  231: 'kick',
#  232: 'stop',
#  233: 'coke',
#  234: 'beverage',
#  235: 'bottom',
#  236: 'plate',
#  237: 'hug',
#  238: 'handle',
#  239: 'coffee',
#  240: 'edge',
#  241: 'kind',
#  242: 'rest',
#  243: 'debate',
#  244: 'wrap',
#  245: 'ishoes',
#  246: 'cardboard',
#  247: 'cut',
#  248: 'pass',
#  249: 'dough',
#  250: 'fix',
#  251: 'tool',
#  252: 'sweat',
#  253: 'attempt',
#  254: 'toy',
#  255: 'air',
#  256: 'orange',
#  257: 'foot',
#  258: 'time',
#  259: 'dresser',
#  260: 'cuddle',
#  261: 'oven',
#  262: 'cheese',
#  263: 'push',
#  264: 'weather',
#  265: 'drape',
#  266: 'begin',
#  267: 'hang',
#  268: 'grab',
#  269: 'picture',
#  270: 's',
#  271: 'candy',
#  272: 'window',
#  273: 'twirl',
#  274: 'bunch',
#  275: 'process',
#  276: 'movement',
#  277: 'boo',
#  278: 'hall',
#  279: 'stare',
#  280: 'rise',
#  281: 'pizza',
#  282: 'laugh',
#  283: 'llooked',
#  284: 'chocolate',
#  285: 'ward',
#  286: 'sweep',
#  287: 'bring',
#  288: 'shove',
#  289: 'leg',
#  290: 'dirt',
#  291: 'bread',
#  292: 'key',
#  293: 'wine',
#  294: 'tennis',
#  295: 'fridge',
#  296: 'carry',
#  297: 'wear',
#  298: 'friend',
#  299: 'drop',
#  300: 'pull',
#  301: 'paperwork',
#  302: 'object',
#  303: 'milk',
#  304: 'climb',
#  305: 'slumber',
#  306: 'reflection',
#  307: 'put',
#  308: 'live',
#  309: 'write',
#  310: 'follow',
#  311: 'circle',
#  312: 'watch',
#  313: 'lot',
#  314: 'tablet',
#  315: 'shelve',
#  316: 'office',
#  317: 'television',
#  318: 'pretend',
#  319: 'sponge',
#  320: 'wood',
#  321: 'leftovers',
#  322: 'personlaying',
#  323: 'continue',
#  324: 'examine',
#  325: 'side',
#  326: 'napkin',
#  327: 'swing',
#  328: 'home',
#  329: 'toilet',
#  330: 'hand',
#  331: 'use',
#  332: 'remove',
#  333: 'magazine',
#  334: 'bedside',
#  335: 'shin',
#  336: 'awaken',
#  337: 'lap',
#  338: 'spice',
#  339: 'go',
#  340: 'envelope',
#  341: 'react',
#  342: 'liquids',
#  343: 'cabinet',
#  344: 'sweatshirt',
#  345: 'tea',
#  346: 'backpack/bag',
#  347: 'basement',
#  348: 'lunch',
#  349: 'touch',
#  350: 'cookies',
#  351: 'sleep',
#  352: 'pour',
#  353: 'resume',
#  354: 'cabinets',
#  355: 'drink',
#  356: 'place',
#  357: 'study',
#  358: 'glass',
#  359: 'break',
#  360: 'cookie',
#  361: 'ring',
#  362: 'sink',
#  363: 'stave',
#  364: 'give',
#  365: 'cleaner',
#  366: 'door',
#  367: 'box',
#  368: 'flick',
#  369: 'runnings',
#  370: 'bowl',
#  371: 'ans',
#  372: 'bottle',
#  373: 'whats',
#  374: 'open/close',
#  375: 'cracker',
#  376: 'hallway',
#  377: 'lid',
#  378: 'nest',
#  379: 'call',
#  380: 'bathroom',
#  381: 'pan',
#  382: 'video',
#  383: 'carpet',
#  384: 'things',
#  385: 'packet',
#  386: 'laptop',
#  387: 'walk-in',
#  388: 'jacket',
#  389: 'pocket',
#  390: 'complain',
#  391: "'ve",
#  392: 'shutter',
#  393: 'check',
#  394: 'homework',
#  395: 'cereal',
#  396: 'rice',
#  397: 'floor',
#  398: 'pajamas',
#  399: 'star',
#  400: 'palce',
#  401: 'bucket',
#  402: 'leave',
#  403: 'self',
#  404: 'message',
#  405: 'noise',
#  406: 'towel',
#  407: 'thermos',
#  408: 'washer',
#  409: 'hinge',
#  410: 'coat',
#  411: 'slide',
#  412: 'frig',
#  413: 'even',
#  414: 'hat',
#  415: 'house',
#  416: 'stairway',
#  417: 'trash',
#  418: 'walk',
#  419: 'swallow',
#  420: 'see',
#  421: 'shoot',
#  422: 'item',
#  423: 'approach',
#  424: 'driveway',
#  425: 'mountain',
#  426: 'notebook',
#  427: 'plastic',
#  428: 'closses',
#  429: 'stuff',
#  430: 'breakfast',
#  431: 'open',
#  432: 'movie',
#  433: 'organize',
#  434: 'outy',
#  435: 'appear',
#  436: 'clean',
#  437: 'stair',
#  438: 'replace',
#  439: 'talk',
#  440: 'look',
#  441: 'make',
#  442: 'set',
#  443: 'egg',
#  444: 'table',
#  445: 'pair',
#  446: 'bite',
#  447: 'straighten',
#  448: 'cup',
#  449: 'fit',
#  450: 'picture/video',
#  451: 'recreation',
#  452: 'spot',
#  453: 'pop',
#  454: 'smile',
#  455: 'page',
#  456: 'container',
#  457: 'sandwich',
#  458: 'flip',
#  459: 'run',
#  460: 'contain',
#  461: 'shut',
#  462: 'shelf',
#  463: 'tv',
#  464: 'search',
#  465: 'wardrobe',
#  466: 'proceed',
#  467: 'shower',
#  468: 'bedtime',
#  469: 'unlace',
#  470: 'reach',
#  471: 'wall',
#  472: 'step',
#  473: 'photos',
#  474: 'conversation',
#  475: 'reenter',
#  476: 'meal',
#  477: 'buy',
#  478: 'something',
#  479: 'dress',
#  480: 'papers/book',
#  481: 'decide',
#  482: 'hold',
#  483: 'sneeze',
#  484: 'dance',
#  485: 'shirt',
#  486: 'win',
#  487: 'seat',
#  488: 'canvas',
#  489: 'wait',
#  490: 'lamp',
#  491: 'whole',
#  492: 'tidy',
#  493: 'cupboard',
#  494: 'curtain',
#  495: 'junk',
#  496: 'doen',
#  497: 'reveal',
#  498: 'word',
#  499: 'burger',
#  500: 'heat',
#  501: 'items',
#  502: 'reference',
#  503: 'minutes',
#  504: 'peel',
#  505: 'pack',
#  506: 'donut',
#  507: 'skillet/pot/pan',
#  508: 'review',
#  509: 'rage',
#  510: 'struggle',
#  511: 'encounter',
#  512: 'doorway',
#  513: 'hoodie/sweater',
#  514: 'texting',
#  515: 'liquid',
#  516: 'apple',
#  517: 'lay',
#  518: 'dump',
#  519: 'can',
#  520: 'laundry',
#  521: 'nap',
#  522: 'book',
#  523: 'fold',
#  524: 'flash',
#  525: 'complete',
#  526: 'garage',
#  527: 'prepare',
#  528: 'eye',
#  529: 'sort',
#  530: 'jump',
#  531: 'bend',
#  532: 'food',
#  533: 'content',
#  534: 'light',
#  535: 'muffin',
#  536: 'shoe',
#  537: 'lend',
#  538: 'device',
#  539: 'sweater',
#  540: 'stack',
#  541: 'bed',
#  542: 'batteries',
#  543: 'beer',
#  544: 'balance',
#  545: 'remember',
#  546: 'add',
#  547: 'room',
#  548: 'knife',
#  549: 'exit',
#  550: 'manner',
#  551: 'dish',
#  552: 'potato',
#  553: 'kneel',
#  554: 'grasp',
#  555: 'clothe',
#  556: 'frame',
#  557: 'kleenex',
#  0: 'PAD',
#  558: '<sos>',
#  559: '<eos>'}

# %%
def label_index(queries, vocab_idx):
    out_idx = {}
    for k,v in queries.items():
        v.insert(0, '<sos>')
        v.append('<eos>')
        val = [vocab_idx[i] for i in v]
        out_idx[k] = val 
    return out_idx 

train_idx = label_index(train_words, vocab_idx)

# %%
len(train_idx)
# Out:
# 12408

# %%
test_idx = label_index(test_words, vocab_idx)

# %%
test_idx
# Out:
# {0: [558, 37, 534, 559],
#  1: [558, 458, 534, 559],
#  2: [558, 37, 534, 559],
#  3: [558, 40, 48, 96, 559],
#  4: [558, 40, 269, 307, 559],
#  5: [558, 307, 179, 559],
#  6: [558, 418, 512, 559],
#  7: [558, 431, 366, 559],
#  8: [558, 112, 366, 559],
#  9: [558, 112, 366, 559],
#  10: [558, 459, 8, 559],
#  11: [558, 312, 8, 459, 559],
#  12: [558, 459, 272, 440, 559],
#  13: [558, 97, 104, 559],
#  14: [558, 459, 272, 559],
#  15: [558, 459, 366, 559],
#  16: [558, 97, 104, 559],
#  17: [558, 97, 104, 559],
#  18: [558, 121, 380, 482, 358, 559],
#  19: [558, 100, 179, 559],
#  20: [558, 97, 104, 559],
#  21: [558, 97, 104, 559],
#  22: [558, 204, 203, 559],
#  23: [558, 204, 555, 559],
#  24: [558, 121, 559],
#  25: [558, 336, 218, 559],
#  26: [558, 100, 164, 559],
#  27: [558, 97, 104, 559],
#  28: [558, 100, 448, 559],
#  29: [558, 431, 366, 559],
#  30: [558, 431, 366, 183, 559],
#  31: [558, 100, 448, 559],
#  32: [558, 418, 512, 355, 239, 559],
#  33: [558, 355, 358, 559],
#  34: [558, 307, 536, 559],
#  35: [558, 482, 358, 559],
#  36: [558, 42, 532, 559],
#  37: [558, 40, 46, 42, 457, 559],
#  38: [558, 482, 358, 559],
#  39: [558, 307, 448, 559],
#  40: [558, 121, 512, 482, 358, 559],
#  41: [558, 42, 457, 559],
#  42: [558, 307, 536, 559],
#  43: [558, 482, 448, 559],
#  44: [558, 418, 415, 307, 532, 559],
#  45: [558, 215, 479, 454, 559],
#  46: [558, 355, 358, 559],
#  47: [558, 100, 355, 559],
#  48: [558, 97, 541, 559],
#  49: [558, 40, 479, 559],
#  50: [558, 97, 541, 559],
#  51: [558, 204, 445, 559],
#  52: [558, 204, 536, 559],
#  53: [558, 123, 522, 559],
#  54: [558, 97, 144, 112, 386, 559],
#  55: [558, 40, 8, 121, 482, 179, 559],
#  56: [558, 40, 366, 112, 559],
#  57: [558, 459, 512, 559],
#  58: [558, 459, 172, 559],
#  59: [558, 431, 179, 559],
#  60: [558, 40, 282, 138, 559],
#  61: [558, 266, 138, 559],
#  62: [558, 40, 179, 307, 559],
#  63: [558, 517, 541, 483, 559],
#  64: [558, 40, 541, 185, 483, 559],
#  65: [558, 355, 75, 559],
#  66: [558, 184, 89, 439, 559],
#  67: [558, 100, 89, 559],
#  68: [558, 431, 343, 559],
#  69: [558, 215, 282, 559],
#  70: [558, 97, 180, 559],
#  71: [558, 40, 478, 355, 559],
#  72: [558, 307, 201, 559],
#  73: [558, 431, 13, 559],
#  74: [558, 418, 415, 482, 179, 559],
#  75: [558, 307, 201, 559],
#  76: [558, 37, 534, 559],
#  77: [558, 307, 406, 559],
#  78: [558, 100, 89, 559],
#  79: [558, 138, 462, 559],
#  80: [558, 431, 366, 559],
#  81: [558, 112, 386, 559],
#  82: [558, 100, 269, 559],
#  83: [558, 97, 104, 559],
#  84: [558, 440, 269, 559],
#  85: [558, 307, 269, 559],
#  86: [558, 307, 146, 559],
#  87: [558, 307, 269, 559],
#  88: [558, 40, 5, 454, 559],
#  89: [558, 431, 366, 559],
#  90: [558, 431, 366, 559],
#  91: [558, 282, 226, 559],
#  92: [558, 64, 203, 40, 282, 559],
#  93: [558, 42, 559],
#  94: [558, 100, 532, 559],
#  95: [558, 117, 203, 559],
#  96: [558, 42, 559],
#  97: [558, 431, 98, 559],
#  98: [558, 40, 547, 121, 482, 457, 559],
#  99: [558, 307, 457, 559],
#  100: [558, 355, 448, 559],
#  101: [558, 355, 358, 559],
#  102: [558, 97, 444, 559],
#  103: [558, 100, 406, 559],
#  104: [558, 100, 406, 559],
#  105: [558, 431, 343, 559],
#  106: [558, 418, 380, 482, 551, 559],
#  107: [558, 112, 366, 559],
#  108: [558, 97, 104, 559],
#  109: [558, 266, 478, 282, 559],
#  110: [558, 40, 104, 97, 559],
#  111: [558, 40, 454, 559],
#  112: [558, 431, 43, 559],
#  113: [558, 204, 200, 559],
#  114: [558, 307, 536, 559],
#  115: [558, 307, 448, 559],
#  116: [558, 112, 366, 559],
#  117: [558, 307, 448, 559],
#  118: [558, 431, 272, 559],
#  119: [558, 431, 272, 559],
#  120: [558, 431, 272, 559],
#  121: [558, 439, 89, 559],
#  122: [558, 112, 43, 559],
#  123: [558, 37, 534, 559],
#  124: [558, 40, 406, 479, 559],
#  125: [558, 107, 100, 367, 559],
#  126: [558, 100, 94, 559],
#  127: [558, 100, 367, 559],
#  128: [558, 97, 200, 559],
#  129: [558, 459, 8, 559],
#  130: [558, 97, 397, 559],
#  131: [558, 100, 15, 559],
#  132: [558, 431, 272, 559],
#  133: [558, 100, 120, 559],
#  134: [558, 170, 478, 440, 272, 559],
#  135: [558, 559],
#  136: [558, 440, 272, 559],
#  137: [558, 440, 522, 431, 559],
#  138: [558, 215, 15, 483, 440, 559],
#  139: [558, 40, 203, 483, 559],
#  140: [558, 40, 534, 250, 559],
#  141: [558, 40, 534, 250, 559],
#  142: [558, 40, 534, 250, 559],
#  143: [558, 307, 522, 559],
#  144: [558, 307, 522, 559],
#  145: [558, 100, 89, 559],
#  146: [558, 100, 536, 559],
#  147: [558, 112, 366, 559],
#  148: [558, 100, 89, 559],
#  149: [558, 96, 89, 559],
#  150: [558, 28, 448, 559],
#  151: [558, 307, 555, 559],
#  152: [558, 431, 272, 559],
#  153: [558, 40, 541, 97, 559],
#  154: [558, 40, 541, 97, 559],
#  155: [558, 266, 272, 431, 559],
#  156: [558, 431, 272, 559],
#  157: [558, 40, 541, 97, 559],
#  158: [558, 431, 43, 559],
#  159: [558, 431, 43, 559],
#  160: [558, 431, 43, 559],
#  161: [558, 482, 536, 559],
#  162: [558, 100, 355, 559],
#  163: [558, 40, 445, 204, 559],
#  164: [558, 307, 367, 559],
#  165: [558, 307, 367, 559],
#  166: [558, 307, 384, 559],
#  167: [558, 100, 203, 559],
#  168: [558, 282, 478, 559],
#  169: [558, 266, 478, 282, 559],
#  170: [558, 307, 532, 559],
#  171: [558, 204, 146, 559],
#  172: [558, 204, 146, 559],
#  173: [558, 37, 534, 207, 402, 559],
#  174: [558, 37, 534, 559],
#  175: [558, 40, 203, 244, 483, 559],
#  176: [558, 331, 193, 431, 343, 559],
#  177: [558, 112, 367, 559],
#  178: [558, 112, 367, 49, 40, 464, 559],
#  179: [558, 336, 541, 559],
#  180: [558, 42, 446, 559],
#  181: [558, 40, 164, 483, 559],
#  182: [558, 215, 483, 559],
#  183: [558, 40, 483, 559],
#  184: [558, 40, 532, 307, 559],
#  185: [558, 40, 201, 307, 559],
#  186: [558, 361, 295, 112, 559],
#  187: [558, 112, 98, 559],
#  188: [558, 112, 343, 559],
#  189: [558, 97, 104, 559],
#  190: [558, 97, 104, 559],
#  191: [558, 431, 43, 559],
#  192: [558, 215, 479, 559],
#  193: [558, 431, 366, 559],
#  194: [558, 307, 536, 559],
#  195: [558, 100, 358, 559],
#  196: [558, 229, 386, 559],
#  197: [558, 96, 32, 559],
#  198: [558, 355, 372, 559],
#  199: [558, 100, 386, 559],
#  200: [558, 40, 179, 482, 559],
#  201: [558, 215, 138, 559],
#  202: [558, 40, 336, 559],
#  203: [558, 101, 358, 355, 559],
#  204: [558, 431, 226, 559],
#  205: [558, 431, 272, 559],
#  206: [558, 112, 366, 559],
#  207: [558, 83, 366, 112, 559],
#  208: [558, 418, 179, 482, 559],
#  209: [558, 336, 541, 559],
#  210: [558, 204, 203, 559],
#  211: [558, 40, 551, 307, 559],
#  212: [558, 307, 367, 559],
#  213: [558, 40, 62, 307, 559],
#  214: [558, 100, 355, 559],
#  215: [558, 100, 532, 559],
#  216: [558, 215, 42, 559],
#  217: [558, 112, 343, 559],
#  218: [558, 440, 478, 42, 559],
#  219: [558, 42, 559],
#  220: [558, 431, 366, 446, 3, 559],
#  221: [558, 40, 42, 559],
#  222: [558, 40, 179, 204, 559],
#  223: [558, 431, 295, 559],
#  224: [558, 431, 261, 440, 559],
#  225: [558, 40, 35, 559],
#  226: [558, 138, 559],
#  227: [558, 100, 536, 559],
#  228: [558, 100, 536, 559],
#  229: [558, 307, 555, 559],
#  230: [558, 307, 201, 559],
#  231: [558, 355, 358, 559],
#  232: [558, 479, 559],
#  233: [558, 40, 203, 482, 559],
#  234: [558, 40, 203, 482, 559],
#  235: [558, 100, 146, 559],
#  236: [558, 42, 532, 559],
#  237: [558, 40, 347, 42, 559],
#  238: [558, 517, 397, 170, 559],
#  239: [558, 312, 317, 42, 516, 559],
#  240: [558, 40, 478, 121, 42, 312, 463, 559],
#  241: [558, 42, 457, 559],
#  242: [558, 112, 386, 559],
#  243: [558, 112, 386, 559],
#  244: [558, 454, 386, 559],
#  245: [558, 266, 42, 559],
#  246: [558, 40, 366, 482, 559],
#  247: [558, 332, 3, 42, 559],
#  248: [558, 42, 532, 559],
#  249: [558, 266, 147, 42, 559],
#  250: [558, 112, 366, 559],
#  251: [558, 121, 559],
#  252: [558, 440, 272, 559],
#  253: [558, 40, 43, 431, 559],
#  254: [558, 431, 43, 559],
#  255: [558, 40, 444, 459, 559],
#  256: [558, 282, 559],
#  257: [558, 42, 559],
#  258: [558, 40, 519, 42, 559],
#  259: [558, 42, 478, 559],
#  260: [558, 307, 111, 559],
#  261: [558, 307, 532, 559],
#  262: [558, 42, 559],
#  263: [558, 40, 532, 482, 559],
#  264: [558, 204, 203, 559],
#  265: [558, 204, 203, 559],
#  266: [558, 307, 462, 559],
#  267: [558, 40, 203, 492, 559],
#  268: [558, 40, 534, 37, 559],
#  269: [558, 431, 366, 559],
#  270: [558, 431, 43, 559],
#  271: [558, 112, 493, 559],
#  272: [558, 112, 493, 559],
#  273: [558, 40, 343, 112, 559],
#  274: [558, 100, 164, 559],
#  275: [558, 355, 448, 559],
#  276: [558, 37, 534, 559],
#  277: [558, 37, 534, 559],
#  278: [558, 454, 5, 559],
#  279: [558, 355, 448, 559],
#  280: [558, 100, 522, 559],
#  281: [558, 37, 165, 559],
#  282: [558, 37, 534, 559],
#  283: [558, 37, 534, 559],
#  284: [558, 459, 547, 559],
#  285: [558, 459, 131, 559],
#  286: [558, 40, 555, 204, 559],
#  287: [558, 112, 272, 559],
#  288: [558, 40, 272, 431, 559],
#  289: [558, 40, 457, 483, 559],
#  290: [558, 42, 457, 559],
#  291: [558, 40, 329, 97, 42, 559],
#  292: [558, 40, 380, 355, 448, 559],
#  293: [558, 224, 275, 40, 192, 559],
#  294: [558, 418, 512, 559],
#  295: [558, 40, 406, 307, 559],
#  296: [558, 40, 526, 121, 482, 200, 559],
#  297: [558, 482, 200, 559],
#  298: [558, 37, 68, 559],
#  299: [558, 418, 512, 559],
#  300: [558, 37, 534, 559],
#  301: [558, 40, 534, 418, 37, 559],
#  302: [558, 40, 75, 352, 559],
#  303: [558, 40, 397, 97, 559],
#  304: [558, 117, 200, 559],
#  305: [558, 266, 370, 42, 559],
#  306: [558, 42, 478, 559],
#  307: [558, 482, 200, 559],
#  308: [558, 97, 397, 559],
#  309: [558, 42, 40, 517, 559],
#  310: [558, 42, 532, 559],
#  311: [558, 97, 104, 559],
#  312: [558, 97, 104, 559],
#  313: [558, 40, 272, 440, 559],
#  314: [558, 440, 380, 559],
#  315: [558, 100, 89, 559],
#  316: [558, 100, 355, 559],
#  317: [558, 204, 397, 559],
#  318: [558, 37, 534, 559],
#  319: [558, 37, 534, 559],
#  320: [558, 37, 534, 559],
#  321: [558, 100, 522, 559],
#  322: [558, 100, 522, 559],
#  323: [558, 40, 522, 492, 559],
#  324: [558, 97, 104, 559],
#  325: [558, 282, 559],
#  326: [558, 100, 269, 559],
#  327: [558, 100, 269, 559],
#  328: [558, 307, 89, 559],
#  329: [558, 28, 330, 559],
#  330: [558, 96, 89, 559],
#  331: [558, 100, 269, 559],
#  332: [558, 96, 89, 559],
#  333: [558, 229, 386, 559],
#  334: [558, 121, 137, 559],
#  335: [558, 204, 536, 231, 559],
#  336: [558, 266, 138, 559],
#  337: [558, 431, 43, 559],
#  338: [558, 204, 200, 559],
#  339: [558, 355, 358, 559],
#  340: [558, 482, 179, 559],
#  341: [558, 28, 555, 559],
#  342: [558, 40, 555, 28, 559],
#  343: [558, 40, 520, 138, 559],
#  344: [558, 100, 406, 559],
#  345: [558, 40, 520, 138, 559],
#  346: [558, 73, 555, 559],
#  347: [558, 439, 406, 559],
#  348: [558, 459, 547, 282, 559],
#  349: [558, 459, 547, 559],
#  350: [558, 459, 308, 559],
#  351: [558, 100, 355, 559],
#  352: [558, 112, 366, 559],
#  353: [558, 307, 358, 559],
#  354: [558, 431, 366, 559],
#  355: [558, 431, 366, 559],
#  356: [558, 100, 406, 559],
#  357: [558, 40, 104, 487, 559],
#  358: [558, 42, 532, 559],
#  359: [558, 100, 446, 559],
#  360: [558, 215, 483, 559],
#  361: [558, 307, 478, 559],
#  362: [558, 307, 536, 559],
#  363: [558, 307, 536, 559],
#  364: [558, 336, 328, 559],
#  365: [558, 482, 406, 418, 219, 559],
#  366: [558, 28, 358, 559],
#  367: [558, 336, 380, 482, 89, 559],
#  368: [558, 100, 406, 559],
#  369: [558, 282, 559],
#  370: [558, 482, 406, 559],
#  371: [558, 418, 406, 482, 559],
#  372: [558, 215, 522, 123, 559],
#  373: [558, 482, 448, 559],
#  374: [558, 418, 46, 482, 358, 559],
#  375: [558, 431, 366, 559],
#  376: [558, 431, 366, 559],
#  377: [558, 431, 366, 559],
#  378: [558, 431, 366, 559],
#  379: [558, 138, 559],
#  380: [558, 459, 131, 559],
#  381: [558, 204, 555, 559],
#  382: [558, 459, 308, 559],
#  383: [558, 100, 555, 559],
#  384: [558, 553, 397, 439, 89, 559],
#  385: [558, 439, 89, 559],
#  386: [558, 352, 478, 559],
#  387: [558, 439, 89, 559],
#  388: [558, 215, 555, 138, 559],
#  389: [558, 112, 366, 559],
#  390: [558, 112, 366, 559],
#  391: [558, 112, 366, 559],
#  392: [558, 266, 138, 559],
#  393: [558, 112, 366, 559],
#  394: [558, 112, 13, 559],
#  395: [558, 97, 397, 123, 522, 559],
#  396: [558, 42, 321, 559],
#  397: [558, 100, 532, 559],
#  398: [558, 431, 98, 559],
#  399: [558, 215, 532, 42, 559],
#  400: [558, 431, 98, 559],
#  401: [558, 100, 406, 559],
#  402: [558, 431, 366, 559],
#  403: [558, 482, 406, 559],
#  404: [558, 483, 5, 40, 482, 559],
#  405: [558, 215, 483, 559],
#  406: [558, 100, 522, 559],
#  407: [558, 100, 522, 559],
#  408: [558, 100, 522, 559],
#  409: [558, 352, 239, 559],
#  410: [558, 307, 448, 559],
#  411: [558, 352, 448, 559],
#  412: [558, 40, 386, 307, 559],
#  413: [558, 312, 317, 559],
#  414: [558, 307, 386, 559],
#  415: [558, 37, 534, 559],
#  416: [558, 420, 366, 112, 559],
#  417: [558, 37, 534, 559],
#  418: [558, 40, 536, 420, 204, 559],
#  419: [558, 100, 446, 559],
#  420: [558, 97, 457, 42, 559],
#  421: [558, 312, 317, 559],
#  422: [558, 100, 269, 559],
#  423: [558, 28, 358, 559],
#  424: [558, 42, 236, 559],
#  425: [558, 307, 179, 559],
#  426: [558, 492, 203, 559],
#  427: [558, 307, 386, 559],
#  428: [558, 121, 559],
#  429: [558, 307, 386, 559],
#  430: [558, 40, 522, 440, 559],
#  431: [558, 431, 522, 559],
#  432: [558, 215, 358, 355, 559],
#  433: [558, 459, 394, 559],
#  434: [558, 431, 98, 559],
#  435: [558, 215, 522, 123, 559],
#  436: [558, 282, 559],
#  437: [558, 282, 446, 559],
#  438: [558, 431, 366, 559],
#  439: [558, 418, 512, 559],
#  440: [558, 431, 366, 559],
#  441: [558, 215, 42, 559],
#  442: [558, 42, 370, 559],
#  443: [558, 418, 547, 42, 532, 559],
#  444: [558, 112, 366, 559],
#  445: [558, 442, 179, 207, 482, 559],
#  446: [558, 307, 179, 40, 482, 559],
#  447: [558, 307, 179, 559],
#  448: [558, 431, 366, 559],
#  449: [558, 482, 104, 431, 98, 559],
#  450: [558, 431, 98, 559],
#  451: [558, 112, 98, 559],
#  452: [558, 100, 532, 559],
#  453: [558, 42, 457, 559],
#  454: [558, 42, 532, 559],
#  455: [558, 431, 343, 559],
#  456: [558, 42, 430, 559],
#  457: [558, 431, 354, 559],
#  458: [558, 459, 203, 230, 559],
#  459: [558, 215, 454, 559],
#  460: [558, 431, 367, 559],
#  461: [558, 40, 367, 483, 559],
#  462: [558, 431, 71, 559],
#  463: [558, 307, 448, 559],
#  464: [558, 215, 282, 559],
#  465: [558, 282, 259, 177, 559],
#  466: [558, 97, 541, 304, 73, 559],
#  467: [558, 40, 541, 336, 559],
#  468: [558, 97, 104, 559],
#  469: [558, 100, 203, 559],
#  470: [558, 97, 104, 355, 478, 559],
#  471: [558, 121, 559],
#  472: [558, 40, 454, 559],
#  473: [558, 40, 226, 121, 282, 559],
#  474: [558, 307, 532, 559],
#  475: [558, 35, 457, 559],
#  476: [558, 307, 203, 559],
#  477: [558, 40, 203, 420, 117, 559],
#  478: [558, 431, 366, 559],
#  479: [558, 431, 43, 559],
#  480: [558, 112, 366, 559],
#  481: [558, 307, 203, 559],
#  482: [558, 40, 203, 117, 559],
#  483: [558, 100, 355, 559],
#  484: [558, 352, 533, 559],
#  485: [558, 352, 358, 559],
#  486: [558, 100, 355, 559],
#  487: [558, 352, 75, 559],
#  488: [558, 352, 27, 559],
#  489: [558, 431, 343, 559],
#  490: [558, 112, 343, 559],
#  491: [558, 100, 200, 559],
#  492: [558, 100, 200, 559],
#  493: [558, 418, 512, 402, 547, 559],
#  494: [558, 418, 512, 559],
#  495: [558, 431, 343, 559],
#  496: [558, 40, 343, 431, 559],
#  497: [558, 112, 343, 559],
#  498: [558, 482, 330, 559],
#  499: [558, 307, 406, 559],
#  500: [558, 215, 356, 459, 559],
#  501: [558, 307, 445, 559],
#  502: [558, 266, 356, 459, 559],
#  503: [558, 215, 356, 459, 559],
#  504: [558, 215, 5, 312, 559],
#  505: [558, 215, 400, 459, 559],
#  506: [558, 215, 356, 459, 559],
#  507: [558, 40, 363, 35, 559],
#  508: [558, 307, 200, 559],
#  509: [558, 331, 269, 100, 559],
#  510: [558, 100, 269, 559],
#  511: [558, 418, 380, 482, 120, 559],
#  512: [558, 307, 179, 559],
#  513: [558, 307, 444, 559],
#  514: [558, 40, 179, 482, 559],
#  515: [558, 40, 201, 307, 559],
#  516: [558, 431, 179, 559],
#  517: [558, 459, 380, 554, 200, 559],
#  518: [558, 459, 380, 482, 200, 559],
#  519: [558, 40, 203, 482, 559],
#  520: [558, 459, 43, 559],
#  521: [558, 459, 547, 559],
#  522: [558, 307, 555, 559],
#  523: [558, 482, 540, 559],
#  524: [558, 331, 116, 42, 448, 559],
#  525: [558, 42, 139, 559],
#  526: [558, 307, 444, 559],
#  527: [558, 37, 534, 559],
#  528: [558, 48, 534, 559],
#  529: [558, 37, 534, 559],
#  530: [558, 266, 138, 559],
#  531: [558, 40, 120, 307, 559],
#  532: [558, 479, 559],
#  533: [558, 100, 372, 559],
#  534: [558, 100, 164, 559],
#  535: [558, 431, 343, 559],
#  536: [558, 112, 343, 559],
#  537: [558, 440, 272, 559],
#  538: [558, 170, 479, 559],
#  539: [558, 459, 526, 559],
#  540: [558, 100, 269, 559],
#  541: [558, 121, 559],
#  542: [558, 355, 448, 559],
#  543: [558, 40, 532, 42, 559],
#  544: [558, 40, 317, 312, 559],
#  545: [558, 42, 367, 559],
#  546: [558, 312, 317, 559],
#  547: [558, 312, 317, 559],
#  548: [558, 40, 146, 482, 559],
#  549: [558, 307, 146, 559],
#  550: [558, 431, 343, 170, 448, 559],
#  551: [558, 121, 512, 482, 146, 559],
#  552: [558, 352, 448, 559],
#  553: [558, 112, 522, 559],
#  554: [558, 266, 483, 559],
#  555: [558, 40, 465, 138, 559],
#  556: [558, 40, 180, 97, 559],
#  557: [558, 97, 218, 559],
#  558: [558, 100, 536, 559],
#  559: [558, 100, 536, 559],
#  560: [558, 355, 75, 559],
#  561: [558, 100, 445, 559],
#  562: [558, 97, 180, 559],
#  563: [558, 355, 75, 559],
#  564: [558, 482, 406, 559],
#  565: [558, 40, 483, 559],
#  566: [558, 100, 406, 559],
#  567: [558, 431, 367, 559],
#  568: [558, 42, 478, 559],
#  569: [558, 40, 547, 418, 42, 457, 559],
#  570: [558, 332, 344, 559],
#  571: [558, 215, 138, 559],
#  572: [558, 100, 344, 559],
#  573: [558, 100, 513, 559],
#  574: [558, 42, 532, 559],
#  575: [558, 40, 200, 117, 559],
#  576: [558, 117, 200, 559],
#  577: [558, 215, 42, 559],
#  578: [558, 184, 448, 355, 559],
#  579: [558, 42, 559],
#  580: [558, 42, 559],
#  581: [558, 355, 448, 559],
#  582: [558, 40, 308, 459, 559],
#  583: [558, 42, 457, 559],
#  584: [558, 266, 311, 459, 559],
#  585: [558, 459, 547, 559],
#  586: [558, 100, 446, 559],
#  587: [558, 323, 459, 559],
#  588: [558, 215, 459, 559],
#  589: [558, 123, 522, 559],
#  590: [558, 123, 522, 559],
#  591: [558, 40, 397, 97, 312, 317, 559],
#  592: [558, 440, 269, 559],
#  593: [558, 482, 269, 559],
#  594: [558, 266, 457, 42, 559],
#  595: [558, 307, 203, 559],
#  596: [558, 431, 366, 559],
#  597: [558, 100, 445, 559],
#  598: [558, 307, 457, 559],
#  599: [558, 100, 179, 559],
#  600: [558, 418, 226, 431, 343, 559],
#  601: [558, 100, 269, 559],
#  602: [558, 100, 269, 559],
#  603: [558, 307, 444, 559],
#  604: [558, 40, 454, 559],
#  605: [558, 431, 43, 559],
#  606: [558, 112, 43, 559],
#  607: [558, 112, 366, 559],
#  608: [558, 431, 43, 559],
#  609: [558, 307, 462, 559],
#  610: [558, 40, 522, 307, 559],
#  611: [558, 215, 448, 355, 559],
#  612: [558, 307, 522, 559],
#  613: [558, 40, 367, 307, 559],
#  614: [558, 482, 246, 36, 226, 559],
#  615: [558, 121, 559],
#  616: [558, 37, 534, 559],
#  617: [558, 215, 138, 559],
#  618: [558, 37, 534, 559],
#  619: [558, 307, 522, 559],
#  620: [558, 282, 152, 559],
#  621: [558, 282, 313, 559],
#  622: [558, 40, 120, 282, 559],
#  623: [558, 431, 522, 559],
#  624: [558, 454, 522, 559],
#  625: [558, 307, 536, 559],
#  626: [558, 100, 536, 559],
#  627: [558, 482, 536, 559],
#  628: [558, 100, 536, 559],
#  629: [558, 121, 454, 559],
#  630: [558, 40, 179, 431, 559],
#  631: [558, 100, 355, 559],
#  632: [558, 431, 367, 559],
#  633: [558, 112, 522, 559],
#  634: [558, 40, 336, 559],
#  635: [558, 307, 536, 559],
#  636: [558, 559],
#  637: [558, 37, 534, 559],
#  638: [558, 37, 534, 559],
#  639: [558, 44, 367, 559],
#  640: [558, 418, 512, 559],
#  641: [558, 40, 444, 97, 559],
#  642: [558, 266, 444, 492, 559],
#  643: [558, 440, 272, 434, 559],
#  644: [558, 42, 532, 559],
#  645: [558, 40, 269, 440, 559],
#  646: [558, 40, 42, 559],
#  647: [558, 266, 457, 42, 559],
#  648: [558, 312, 478, 559],
#  649: [558, 440, 269, 559],
#  650: [558, 431, 386, 20, 229, 559],
#  651: [558, 215, 386, 229, 559],
#  652: [558, 40, 454, 559],
#  653: [558, 40, 358, 355, 559],
#  654: [558, 355, 358, 559],
#  655: [558, 266, 75, 355, 559],
#  656: [558, 40, 483, 559],
#  657: [558, 184, 146, 559],
#  658: [558, 355, 358, 559],
#  659: [558, 307, 536, 559],
#  660: [558, 266, 536, 307, 559],
#  661: [558, 466, 445, 121, 307, 559],
#  662: [558, 40, 89, 282, 559],
#  663: [558, 355, 358, 559],
#  664: [558, 37, 534, 559],
#  665: [558, 40, 534, 250, 559],
#  666: [558, 37, 534, 559],
#  667: [558, 355, 358, 559],
#  668: [558, 112, 522, 559],
#  669: [558, 112, 320, 559],
#  670: [558, 40, 555, 336, 559],
#  671: [558, 112, 366, 559],
#  672: [558, 112, 366, 559],
#  673: [558, 440, 272, 559],
#  674: [558, 97, 104, 559],
#  675: [558, 97, 541, 559],
#  676: [558, 307, 236, 559],
#  677: [558, 97, 104, 42, 478, 559],
#  678: [558, 40, 180, 97, 42, 532, 559],
#  679: [558, 42, 532, 559],
#  680: [558, 307, 532, 559],
#  681: [558, 112, 366, 559],
#  682: [558, 40, 199, 483, 559],
#  683: [558, 307, 179, 559],
#  684: [558, 97, 218, 123, 522, 559],
#  685: [558, 97, 218, 559],
#  686: [558, 431, 367, 559],
#  687: [558, 431, 522, 559],
#  688: [558, 431, 367, 559],
#  689: [558, 431, 367, 559],
#  690: [558, 215, 483, 559],
#  691: [558, 100, 89, 559],
#  692: [558, 250, 169, 559],
#  693: [558, 97, 180, 559],
#  694: [558, 40, 380, 112, 559],
#  695: [558, 112, 366, 559],
#  696: [558, 459, 179, 559],
#  697: [558, 481, 179, 459, 559],
#  698: [558, 40, 269, 204, 559],
#  699: [558, 40, 42, 559],
#  700: [558, 42, 3, 559],
#  701: [558, 355, 358, 559],
#  702: [558, 42, 457, 559],
#  703: [558, 28, 551, 559],
#  704: [558, 100, 367, 559],
#  705: [558, 307, 536, 559],
#  706: [558, 459, 559],
#  707: [558, 459, 547, 559],
#  708: [558, 307, 536, 559],
#  709: [558, 307, 536, 559],
#  710: [558, 307, 536, 559],
#  711: [558, 431, 366, 339, 547, 559],
#  712: [558, 431, 366, 559],
#  713: [558, 431, 193, 559],
#  714: [558, 215, 356, 459, 559],
#  715: [558, 215, 356, 459, 559],
#  716: [558, 204, 146, 559],
#  717: [558, 215, 483, 559],
#  718: [558, 431, 366, 559],
#  719: [558, 431, 366, 559],
#  720: [558, 40, 200, 554, 559],
#  721: [558, 100, 532, 559],
#  722: [558, 307, 532, 559],
#  723: [558, 28, 330, 559],
#  724: [558, 40, 313, 20, 559],
#  725: [558, 35, 478, 559],
#  726: [558, 431, 13, 559],
#  727: [558, 355, 239, 559],
#  728: [558, 355, 358, 559],
#  729: [558, 431, 98, 559],
#  730: [558, 431, 98, 559],
#  731: [558, 431, 98, 559],
#  732: [558, 431, 366, 559],
#  733: [558, 112, 366, 559],
#  734: [558, 97, 104, 559],
#  735: [558, 112, 366, 559],
#  736: [558, 97, 104, 559],
#  737: [558, 282, 463, 559],
#  738: [558, 282, 317, 559],
#  739: [558, 336, 131, 559],
#  740: [558, 282, 463, 559],
#  741: [558, 100, 92, 559],
#  742: [558, 83, 92, 307, 559],
#  743: [558, 37, 559],
#  744: [558, 534, 559],
#  745: [558, 250, 534, 559],
#  746: [558, 204, 291, 559],
#  747: [558, 418, 512, 559],
#  748: [558, 140, 142, 336, 559],
#  749: [558, 431, 43, 559],
#  750: [558, 307, 146, 559],
#  751: [558, 431, 366, 559],
#  752: [558, 112, 366, 559],
#  753: [558, 307, 146, 559],
#  754: [558, 431, 366, 559],
#  755: [558, 112, 366, 559],
#  756: [558, 440, 269, 559],
#  757: [558, 100, 128, 559],
#  758: [558, 23, 193, 559],
#  759: [558, 431, 366, 559],
#  760: [558, 83, 366, 431, 559],
#  761: [558, 40, 104, 97, 559],
#  762: [558, 37, 534, 559],
#  763: [558, 170, 534, 37, 559],
#  764: [558, 418, 534, 559],
#  765: [558, 204, 203, 559],
#  766: [558, 100, 269, 559],
#  767: [558, 204, 406, 559],
#  768: [558, 431, 13, 307, 444, 559],
#  769: [558, 100, 355, 559],
#  770: [558, 355, 448, 559],
#  771: [558, 42, 457, 559],
#  772: [558, 431, 343, 559],
#  773: [558, 40, 91, 96, 559],
#  774: [558, 40, 457, 42, 559],
#  775: [558, 100, 269, 559],
#  776: [558, 100, 269, 559],
#  777: [558, 40, 104, 436, 97, 559],
#  778: [558, 97, 104, 559],
#  779: [558, 40, 357, 454, 482, 179, 559],
#  780: [558, 37, 534, 559],
#  781: [558, 250, 394, 559],
#  782: [558, 42, 541, 559],
#  783: [558, 42, 478, 559],
#  784: [558, 97, 541, 559],
#  785: [558, 100, 269, 559],
#  786: [558, 28, 330, 559],
#  787: [558, 408, 330, 559],
#  788: [558, 307, 522, 559],
#  789: [558, 40, 536, 307, 559],
#  790: [558, 307, 536, 559],
#  791: [558, 307, 536, 559],
#  792: [558, 482, 445, 559],
#  793: [558, 121, 559],
#  794: [558, 307, 536, 559],
#  795: [558, 42, 532, 559],
#  796: [558, 40, 522, 204, 559],
#  797: [558, 459, 325, 559],
#  798: [558, 40, 541, 97, 559],
#  799: [558, 459, 131, 559],
#  800: [558, 352, 478, 559],
#  801: [558, 352, 75, 559],
#  802: [558, 40, 483, 559],
#  803: [558, 355, 358, 559],
#  804: [558, 339, 459, 559],
#  805: [558, 431, 559],
#  806: [558, 431, 559],
#  807: [558, 459, 547, 559],
#  808: [558, 40, 420, 42, 559],
#  809: [558, 40, 104, 97, 559],
#  810: [558, 42, 478, 559],
#  811: [558, 268, 200, 117, 559],
#  812: [558, 97, 104, 42, 559],
#  813: [558, 482, 200, 559],
#  814: [558, 42, 236, 559],
#  815: [558, 312, 317, 559],
#  816: [558, 215, 317, 312, 559],
#  817: [558, 312, 317, 559],
#  818: [558, 97, 240, 559],
#  819: [558, 40, 345, 355, 559],
#  820: [558, 204, 179, 559],
#  821: [558, 282, 559],
#  822: [558, 215, 179, 282, 307, 559],
#  823: [558, 100, 536, 559],
#  824: [558, 40, 179, 482, 559],
#  825: [558, 100, 536, 559],
#  826: [558, 431, 343, 559],
#  827: [558, 307, 386, 559],
#  828: [558, 40, 532, 42, 559],
#  829: [558, 100, 446, 559],
#  830: [558, 431, 366, 559],
#  831: [558, 482, 200, 559],
#  832: [558, 112, 295, 559],
#  833: [558, 37, 534, 559],
#  834: [558, 28, 330, 559],
#  835: [558, 37, 534, 559],
#  836: [558, 100, 542, 559],
#  837: [558, 40, 397, 97, 204, 200, 559],
#  838: [558, 100, 536, 559],
#  839: [558, 97, 104, 559],
#  840: [558, 97, 104, 559],
#  841: [558, 100, 536, 559],
#  842: [558, 40, 179, 482, 559],
#  843: [558, 40, 27, 355, 559],
#  844: [558, 323, 372, 355, 559],
#  845: [558, 355, 358, 559],
#  846: [558, 42, 532, 559],
#  847: [558, 42, 457, 559],
#  848: [558, 459, 43, 559],
#  849: [558, 100, 203, 559],
#  850: [558, 307, 555, 559],
#  851: [558, 100, 124, 559],
#  852: [558, 483, 559],
#  853: [558, 440, 272, 559],
#  854: [558, 28, 330, 559],
#  855: [558, 323, 272, 440, 559],
#  856: [558, 40, 330, 28, 559],
#  857: [558, 28, 330, 559],
#  858: [558, 440, 272, 559],
#  859: [558, 40, 547, 121, 312, 317, 559],
#  860: [558, 355, 478, 559],
#  861: [558, 355, 358, 559],
#  862: [558, 40, 317, 312, 559],
#  863: [558, 204, 200, 559],
#  864: [558, 42, 457, 559],
#  865: [558, 37, 534, 559],
#  866: [558, 37, 534, 559],
#  867: [558, 37, 534, 559],
#  868: [558, 97, 541, 559],
#  869: [558, 307, 457, 559],
#  870: [558, 307, 444, 559],
#  871: [558, 204, 532, 559],
#  872: [558, 112, 366, 559],
#  873: [558, 352, 358, 559],
#  874: [558, 352, 358, 559],
#  875: [558, 355, 233, 559],
#  876: [558, 112, 366, 559],
#  877: [558, 307, 422, 559],
#  878: [558, 40, 179, 431, 559],
#  879: [558, 307, 179, 559],
#  880: [558, 204, 200, 559],
#  881: [558, 40, 200, 482, 559],
#  882: [558, 204, 200, 559],
#  883: [558, 40, 43, 431, 440, 457, 559],
#  884: [558, 431, 366, 559],
#  885: [558, 431, 366, 559],
#  886: [558, 312, 317, 559],
#  887: [558, 112, 386, 559],
#  888: [558, 215, 532, 42, 559],
#  889: [558, 184, 457, 42, 559],
#  890: [558, 336, 397, 559],
#  891: [558, 418, 272, 559],
#  892: [558, 40, 397, 517, 559],
#  893: [558, 431, 272, 559],
#  894: [558, 431, 494, 440, 272, 559],
#  895: [558, 138, 84, 559],
#  896: [558, 100, 200, 559],
#  897: [558, 117, 200, 559],
#  898: [558, 100, 269, 559],
#  899: [558, 42, 559],
#  900: [558, 266, 42, 559],
#  901: [558, 37, 534, 559],
#  902: [558, 37, 534, 559],
#  903: [558, 37, 534, 559],
#  904: [558, 37, 534, 559],
#  905: [558, 431, 386, 559],
#  906: [558, 431, 386, 559],
#  907: [558, 307, 146, 559],
#  908: [558, 42, 532, 559],
#  909: [558, 42, 478, 559],
#  910: [558, 40, 42, 559],
#  911: [558, 431, 98, 559],
#  912: [558, 40, 366, 112, 559],
#  913: [558, 483, 406, 559],
#  914: [558, 431, 98, 559],
#  915: [558, 483, 406, 559],
#  916: [558, 40, 5, 483, 153, 559],
#  917: [558, 204, 179, 559],
#  918: [558, 307, 444, 559],
#  919: [558, 266, 179, 307, 559],
#  920: [558, 482, 179, 559],
#  921: [558, 418, 512, 559],
#  922: [558, 40, 522, 440, 482, 155, 559],
#  923: [558, 418, 512, 559],
#  924: [558, 40, 478, 35, 559],
#  925: [558, 355, 448, 559],
#  926: [558, 97, 444, 559],
#  927: [558, 97, 104, 559],
#  928: [558, 35, 363, 559],
#  929: [558, 307, 203, 559],
#  930: [558, 307, 444, 559],
#  931: [558, 307, 462, 559],
#  932: [558, 112, 367, 559],
#  933: [558, 307, 478, 112, 366, 559],
#  934: [558, 112, 366, 559],
#  935: [558, 307, 522, 559],
#  936: [558, 100, 343, 431, 559],
#  937: [558, 459, 43, 559],
#  938: [558, 459, 226, 559],
#  939: [558, 266, 459, 559],
#  940: [558, 459, 180, 559],
#  941: [558, 307, 448, 559],
#  942: [558, 418, 457, 42, 559],
#  943: [558, 40, 457, 42, 559],
#  944: [558, 100, 355, 559],
#  945: [558, 40, 483, 559],
#  946: [558, 112, 366, 559],
#  947: [558, 112, 366, 559],
#  948: [558, 83, 193, 250, 559],
#  949: [558, 42, 559],
#  950: [558, 323, 42, 559],
#  951: [558, 42, 457, 559],
#  952: [558, 40, 193, 250, 559],
#  953: [558, 312, 298, 250, 366, 559],
#  954: [558, 431, 179, 559],
#  955: [558, 42, 532, 559],
#  956: [558, 42, 478, 559],
#  957: [558, 312, 463, 42, 457, 559],
#  958: [558, 112, 366, 559],
#  959: [558, 37, 534, 559],
#  960: [558, 112, 366, 559],
#  961: [558, 40, 454, 559],
#  962: [558, 307, 536, 559],
#  963: [558, 40, 454, 559],
#  964: [558, 307, 536, 559],
#  965: [558, 307, 478, 559],
#  966: [558, 307, 448, 559],
#  967: [558, 97, 104, 559],
#  968: [558, 431, 366, 559],
#  969: [558, 97, 104, 559],
#  970: [558, 100, 146, 559],
#  971: [558, 307, 146, 559],
#  972: [558, 97, 104, 559],
#  973: [558, 307, 444, 559],
#  974: [558, 35, 363, 559],
#  975: [558, 40, 203, 482, 559],
#  976: [558, 37, 534, 559],
#  977: [558, 112, 366, 559],
#  978: [558, 112, 366, 559],
#  979: [558, 112, 366, 559],
#  980: [558, 40, 536, 204, 559],
#  981: [558, 204, 536, 559],
#  982: [558, 100, 355, 559],
#  983: [558, 40, 386, 96, 559],
#  984: [558, 107, 459, 559],
#  985: [558, 112, 366, 559],
#  986: [558, 100, 448, 559],
#  987: [558, 123, 522, 559],
#  988: [558, 123, 522, 559],
#  989: [558, 215, 264, 479, 559],
#  990: [558, 266, 479, 559],
#  991: [558, 307, 522, 559],
#  992: [558, 123, 522, 559],
#  993: [558, 97, 541, 559],
#  994: [558, 97, 541, 559],
#  995: [558, 42, 532, 559],
#  996: [558, 97, 541, 559],
#  997: [558, 100, 536, 559],
#  998: [558, 37, 534, 559],
#  999: [558, 40, 366, 112, 559],
#  ...}

# %%
import json 
with open('train_translate.json', 'w') as f:
    json.dump([train_idx, train_words], f)

with open('test_translate.json', 'w') as f:
    json.dump([test_idx, test_words], f)
    
with open('vocab_translate.json', 'w') as f:
    json.dump([vocab_idx, idx_vocab], f)
